# %%
import SensorOptimizers.ManualDesign as MD
import numpy as np
import pickle

ROS = True
epsilon = 0.5
multi_objective = False
sensorNum = 13
initial_state = 'random'

# maxSensorNum = int(np.min([(8 / epsilon) * (8 / epsilon), sensorNum]))

print('----- Running Expert Placement with: \n \t - epsilon: ', epsilon, 
      '\n \t - sensor #:', sensorNum, 
      ' \n \t - initial state: ', initial_state)


config = {'x1': 0.5 / epsilon,  'y1': 3 / epsilon,    't1':1,
          'x2': 2 / epsilon,    'y2': 4 / epsilon,    't2':1,
          'x3': 0.5 / epsilon,  'y3': 6 / epsilon,    't3':1,
          'x4': 2 / epsilon,    'y4': 6 / epsilon,    't4':1,
          'x5': 2.5 / epsilon,  'y5': 7.5 / epsilon,  't5':1,
          'x6': 0.5 / epsilon,  'y6': 7.5 / epsilon,  't6':1,
          'x7': 3.5 / epsilon,  'y7': 7 / epsilon,    't7':1,
          'x8': 7.5 / epsilon,  'y8': 7.5 / epsilon,  't8':1,
          'x9': 7 / epsilon,    'y9': 6 / epsilon,    't9':1,
          'x10': 7.5 / epsilon, 'y10': 4 / epsilon,   't10':1,
          'x11': 6.5 / epsilon, 'y11': 4 / epsilon,   't11':1,
          'x12': 5 / epsilon,   'y12': 3 / epsilon,   't12':1,
          'x13': 7.5 / epsilon, 'y13': 1.5 / epsilon, 't13':1,
         }

histories = []

for _ in range(5):
    history = MD.run(config,
                     run_on_colab = False,
                     epsilon = epsilon, 
                     ROS = True, 
                     LSmaxSensorNum = int(len(config) / 3),
                     ISmaxSensorNum = int(len(config) / 3),
                     radius = 1,
                     print_epochs = True,
                     height = 8.0,
                     width = 8.0,
                     input_sensor_types = {'model_motion_sensor': True, 
                                           'model_beacon_sensor': False,
                                           'model_pressure_sensor': False,
                                           'model_accelerometer': False,
                                           'model_electricity_sensor': False},
                    )

    print(history)
    histories.append(history)
    
print('------')
print(100 - np.mean(histories))
print(np.std(histories))
# Out:
# ----- Running Expert Placement with:
#  	 - epsilon:  0.5
#  	 - sensor #: 13
#  	 - initial state:  random
# 22.222802056430353
# 24.01489946294575
# 24.11372748860201
# 22.957218901152956
# 22.01189167728637
# ------
# 23.064107917283486
# 0.8754525271865478

# %%
print('------')
print(100 - np.mean(histories))
print(np.std(histories))
# Out:
# ------
# 76.93589208271652
# 0.8754525271865478

# %% [raw]
# import SensorOptimizers.ManualDesign as MD
# import numpy as np
# import pickle
#
# ROS = True
# epsilon = 1
# multi_objective = False
# sensorNum = 5
# initial_state = 'random'
#
# # maxSensorNum = int(np.min([(8 / epsilon) * (8 / epsilon), sensorNum]))
#
# # print('----- Running BO with: \n \t - epsilon: ', epsilon,
# #       '\n \t - sensor #:', sensorNum,
# #       ' \n \t - initial state: ', initial_state)
#
#
# config = {'x1': 1 / epsilon,
#           'y1': 3 / epsilon,
#
#           'x2': 2 / epsilon,
#           'y2': 5 / epsilon,
#
#           'x3': 1 / epsilon,
#           'y3': 6 / epsilon,
#
#           'x4': 2 / epsilon,
#           'y4': 7 / epsilon,
#
#           'x5': 1 / epsilon,
#           'y5': 7 / epsilon,
#
#           'x6': 7 / epsilon,
#           'y6': 2 / epsilon,
#
#           'x7': 5 / epsilon,
#           'y7': 3 / epsilon,
#
#           'x8': 7 / epsilon,
#           'y8': 4 / epsilon,
#
#           'x9': 7 / epsilon,
#           'y9': 6 / epsilon,
#
#           'x10': 7 / epsilon,
#           'y10': 7 / epsilon,
#
#          }
#
# histories = []
#
# for _ in range(5):
#     history = MD.run(config,
#                      epsilon = epsilon,
#                      ROS = True,
#                      maxSensorNum = int(len(config) / 2)
#                     )
#
#     print(history)
#     histories.append(history)
#
#
# print('------')
# print(np.mean(histories))
# print(np.std(histories))

# %% [raw]
# import SensorOptimizers.ManualDesign as MD
# import numpy as np
# import pickle
#
# ROS = True
# epsilon = 2
# multi_objective = False
# sensorNum = 5
# initial_state = 'random'
#
# # maxSensorNum = int(np.min([(8 / epsilon) * (8 / epsilon), sensorNum]))
#
# # print('----- Running BO with: \n \t - epsilon: ', epsilon,
# #       '\n \t - sensor #:', sensorNum,
# #       ' \n \t - initial state: ', initial_state)
#
#
# config = {'x1': 2 / epsilon,
#           'y1': 2 / epsilon,
#
#           'x2': 2 / epsilon,
#           'y2': 4 / epsilon,
#
#           'x3': 2 / epsilon,
#           'y3': 6 / epsilon,
#
#           'x4': 6 / epsilon,
#           'y4': 2 / epsilon,
#
#           'x5': 6 / epsilon,
#           'y5': 6 / epsilon,
#
#          }
#
# histories = []
#
# for _ in range(5):
#     history = MD.run(config,
#                      epsilon = epsilon,
#                      ROS = True,
#                      maxSensorNum = int(len(config) / 2)
#                     )
#
#     print(history)
#     histories.append(history)
#
# print('------')
# print(np.mean(histories))
# print(np.std(histories))
