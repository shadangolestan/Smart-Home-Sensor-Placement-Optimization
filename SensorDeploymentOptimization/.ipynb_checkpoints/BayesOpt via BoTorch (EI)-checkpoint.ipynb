# %%
# !pip3 install ax-platform
# !pip3 install botorch
# Out:
# Requirement already satisfied: ax-platform in /usr/local/lib/python3.9/site-packages (0.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from ax-platform) (2.11.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/site-packages (from ax-platform) (4.14.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.9/site-packages (from ax-platform) (2.13.0)
# Requirement already satisfied: botorch==0.5.1 in /usr/local/lib/python3.9/site-packages (from ax-platform) (0.5.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from ax-platform) (0.23.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: gpytorch>=1.5.1 in /usr/local/lib/python3.9/site-packages (from botorch==0.5.1->ax-platform) (1.5.1)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch==0.5.1->ax-platform) (1.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from ax-platform) (0.23.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch==0.5.1->ax-platform) (1.10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.9/site-packages (from jinja2->ax-platform) (1.1.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (2020.4)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (1.19.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (2.8.1)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages (from plotly->ax-platform) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.9/site-packages (from plotly->ax-platform) (1.3.3)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages (from plotly->ax-platform) (1.15.0)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages (from plotly->ax-platform) (1.15.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (1.19.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->ax-platform) (2.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from scikit-learn->ax-platform) (0.17.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (1.19.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from torch>=1.8.1->botorch==0.5.1->ax-platform) (3.10.0.2)
# Requirement already satisfied: botorch in /usr/local/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: gpytorch>=1.5.1 in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch) (1.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from gpytorch>=1.5.1->botorch) (0.23.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch) (1.10.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (1.19.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (2.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.4)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (1.19.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from torch>=1.8.1->botorch) (3.10.0.2)

# %%
class Data:
    def __init__(self, sensorPositions, space, epsilon):
        self.radius = 1
        self.placeHolders = sensorPositions
        self.epsilon = epsilon
        self.space = space
        # self.SensorPlaceHolderSetup()
        
    def frange(self, start, stop, step):
        steps = []
        while start <= stop:
            steps.append(start)
            start +=step
            
        return steps

    # def SensorPlaceHolderSetup(self):
    #     Xs = self.frange(0, self.space[0], self.epsilon)
    #     Ys = self.frange(0, self.space[1], self.epsilon)
            
    #     for x in Xs:
    #       for y in Ys:
    #         self.placeHolders.append([x, y])

    def GetSensorConfiguration(self):
        from collections import Counter
        sensorLocations, sensorTypes = self.GetSensorLocations()

        summaryDict = Counter(sensorTypes)

        # TODO: DIFFERENT SENSOR TYPE DEFINITIONS SHOULD BE ADDED HERE:
        configurationSummary = []
        for key in summaryDict:
            if (key == 1):
                configurationSummary.append(['motion sensors', summaryDict[key]])

            elif (key == 2):
                configurationSummary.append(['beacon sensors', summaryDict[key]])

        configurationDetails = []
        for index, loc in enumerate(sensorLocations):
            if (sensorTypes[index] == 1):
                configurationDetails.append(tuple([loc, 'kitchen', 'motion sensors']))

            elif (sensorTypes[index] == 2):
                configurationDetails.append(tuple([loc, 'kitchen', 'beacon sensors']))

        return [[configurationSummary, [tuple(configurationDetails)]], self.radius]


    def GetSensorLocations(self):
        sensorLocations = []
        sensorTypes = []
        for index, sensorIndicator in enumerate(self.placeHolders):
            sensorLocations.append(self.placeHolders[index])

            # TODO: DIFFERENT SENSOR TYPE DEFINITIONS SHOULD BE ADDED HERE:
            sensorTypes.append(1)


        return sensorLocations, sensorTypes


class BOVariables:
    def __init__(self, Data_path, epsilon, initSensorNum, maxSensorNum, radius, sampleSize):
        self.epsilon = epsilon
        self.Data_path = Data_path
        self.initSensorNum = initSensorNum
        self.maxSensorNum = maxSensorNum
        self.radius = radius
        self.sensor_distribution, self.types, self.space, self.rooms, self.agentTraces = self.ModelsInitializations()

    def ModelsInitializations(self):
        #----- Space and agent models -----: 
        simworldname = self.Data_path + '/Configuration Files/simulationWorld2.xml'
        agentTraces = []
        directory = os.fsencode(self.Data_path + 'Agent Trace Files/')
            
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.endswith(".csv"): 
                agentTraces.append(self.Data_path + 'Agent Trace Files/' + filename)

        # Parsing the space model: 
        space, rooms = pf.ParseWorld(simworldname)

        xs = []
        for i in space:
          for j in i:
            xs.append(j)
        A = list(set(xs))
        A.sort()
        space = [A[-1], A[-2]]

        # User parameters 
        types, sensor_distribution = pf.GetUsersParameters()

        roomsList = []
        for room in sensor_distribution:
            roomsList.append(room)
              
        return sensor_distribution, types, space, rooms, agentTraces


def frange(start, stop, step):
    steps = []
    while start <= stop:
        steps.append(start)
        start +=step
        
    return steps

def MakeSensorCombinations(start, end, epsilon, sensorType, room):
    a1, b1 = makeBoundaries(epsilon, start[0], end[0])
    a2, b2 = makeBoundaries(epsilon, start[1], end[1])    
    Xs = frange(a1, b1, epsilon)
    Ys = frange(a2, b2, epsilon)
    
    points = list(itertools.product(list(itertools.product(Xs, Ys)), [room], [sensorType[0]])) 
    C = itertools.combinations(points, distribution[room][types.index(sensorType)])

    return C

def PreProcessor(df):
    # df['motion sensors'] = df['motion sensors'].apply(ast.literal_eval)
    df['motion sensors'] = df['motion sensors'].apply(lambda s: list(map(int, s)))
    # df['beacon sensors'] = df['beacon sensors'].apply(ast.literal_eval)
    try:
      df['beacon sensors'] = df['beacon sensors'].apply(lambda s: list(map(int, s)))
    except:
      pass

    sensors = set([])

    previous_M = None
    previous_B = None
    output_file = []

    for index, row in df.iterrows():
      T = row['time']
      M = row['motion sensors']
      try:
        B = row['beacon sensors']
      except:
        pass

      Activity = row['activity']
      Activity = Activity.replace(' ', '_')
      MotionSensor_Names = []
      sensorNames = []
      MotionSensor_Message = []
      BeaconSensor_Names = []
      BeaconSensor_Message = []
      

      # time = convertTime(T)
      time = "2020-06-16 " + T + ".00"

      # Motion Sensor
      for i in range(len(M)):
        sensorNames.append(Name(i, 'M'))
        if M[i] == 1:
          if (previous_M != None):
            if (previous_M[i] == 0):
              MotionSensor_Names.append(Name(i,'M'))
              MotionSensor_Message.append('ON')

          else:
            MotionSensor_Names.append(Name(i,'M'))
            MotionSensor_Message.append('ON')

        if previous_M != None:
          if M[i] == 0 and previous_M[i] == 1:
            MotionSensor_Names.append(Name(i,'M'))
            MotionSensor_Message.append('OFF')

      previous_M = M
      # Beacon Sensor

      try:
        for i in range(len(B)):
          sensorNames.append(Name(i, 'B'))
          if B[i] == 1:
            BeaconSensor_Names.append(Name(i,'B'))
            BeaconSensor_Message.append('ON')
          if previous_B != None:
            if B[i] == 0 and previous_B[i] == 1: 
              BeaconSensor_Names.append(Name(i,'B'))
              BeaconSensor_Message.append('OFF')
        previous_B = B

      except:
        pass

      for m in range(len(MotionSensor_Names)):
        output_file.append(time +' '+ MotionSensor_Names[m] + ' ' + MotionSensor_Names[m] + ' ' + MotionSensor_Message[m] + ' ' + Activity)
        
      for s in sensorNames:
          sensors.add(s)

    return output_file, list(sensors)

#returns the name of the sensor
def Name(number, typeSensor):
    if number < 10:
      return typeSensor + str(0) + str(number)
    else:
      return typeSensor + str(number)

#converts epoch time to human readable
def convertTime(posix_timestamp):
    tz = pytz.timezone('MST')
    dt = datetime.fromtimestamp(posix_timestamp, tz)
    time = dt.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
    return time

def MakeDataBoundaries(height = 10.5, width = 6.6, MaxSensors = 15):
    from collections import defaultdict, OrderedDict

    d = dict()

    for idx in range(MaxSensors):
            d['x' + str(idx)] = (0.5, width - 0.5)
            d['y' + str(idx)] = (0.5, height - 0.5)

    return d

def black_box_function(sample, simulateMotionSensors = True, simulateEstimotes = False, Plotting = False):       
    files = []

    if (runningOnGoogleColab == True):
        sys.path.append('gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/')
        Data_path = 'gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/'
        
    else:
        sys.path.append('../../Codes/Sensor Simulator/')
        Data_path = '../../Codes/Sensor Simulator/'

    all_sensors = set([])

    for agentTrace in BOV.agentTraces:
        df_ = sim_sis.RunSimulator(BOV.space, BOV.rooms, agentTrace, sample.GetSensorConfiguration(), simulateMotionSensors, simulateEstimotes, Plotting, BOV.Data_path)
        dataFile, sensors = PreProcessor(df_)
        all_sensors.update(sensors)
        files.append(dataFile)
        
    
    if (runningOnGoogleColab == True):
        sys.path.append('gdrive/My Drive/PhD/Thesis/Ideas/Codes/CASAS/AL-Smarthome')

    else:
        sys.path.append('../../Codes/CASAS/AL-Smarthome')

    import al
    import imp
    imp.reload(al)
    all_sensors = list(all_sensors)

    accuracy = (al.leave_one_out(files, all_sensors)[0]) * 100

    if accuracy < 0:
        accuracy = 0

    return [accuracy]

def function_to_be_optimized(T):
    sensorPositions = []
    sensor_xy = []
    for i, item in enumerate(T):
            if i % 2 == 0:
                sensor_xy.append(item)

            else:
                sensor_xy.append(item)  
                sensorPositions.append(sensor_xy)
                sensor_xy = []

    data = Data(sensorPositions, BOV.space, CONSTANTS['epsilon'])
    return torch.Tensor(black_box_function(data))

def InitializeDataset(BOV, init_num = 5):
    train_x = []
    for i in range(init_num):
        Xs = frange(0, BOV.space[0], BOV.epsilon)
        Ys = frange(0, BOV.space[1], BOV.epsilon)
        grid = np.zeros(len(Xs) * len(Ys)).tolist()
        placeHolders = []


        for x in Xs:
            for y in Ys:
                placeHolders.append([x, y])

        i = 0
        while i < BOV.initSensorNum:
            cell = random.randrange(len(grid))
            if grid[cell] == 0:
                grid[cell] = 1
                i += 1

        sensorPositions = []
        sensorTypes = []
        for index, sensorIndicator in enumerate(grid):
            if (sensorIndicator > 0):
                # sensorPositions.append(torch.Tensor(placeHolders[index]))
                sensorPositions.append(placeHolders[index][0])
                sensorPositions.append(placeHolders[index][1])
                sensorTypes.append(torch.Tensor(sensorIndicator))


        sensorPositions = torch.Tensor(sensorPositions)


        # data = Data(sensorPositions, BOV.space, epsilon)
        train_x.append(sensorPositions)

    train_x = torch.stack(train_x)

    train_y = []

    sensorPositions = []
    sensor_xy = []
    for T in train_x:

        for i, item in enumerate(T):
            if i % 2 == 0:
                sensor_xy.append(item)

            else:
                sensor_xy.append(item)  
                sensorPositions.append(sensor_xy)
                sensor_xy = []

        data = Data(sensorPositions, BOV.space, CONSTANTS['epsilon'])
        train_y.append(torch.Tensor(black_box_function(data)))

    train_y = torch.stack(train_y)
    best_observed_value = train_y.max()

    return train_x, train_y, best_observed_value
    

def frange(start, stop, step):
    steps = []
    while start <= stop:
        steps.append(start)
        start +=step
        
    return steps

def get_next_points(train_x, train_y, best_observed_value, bounds, n_points = 1):
    single_model = SingleTaskGP(train_x, train_y)
    mll = ExactMarginalLogLikelihood(single_model.likelihood, single_model)
    fit_gpytorch_model(mll)
    
    print('----- Calculating Next Candidates Point From the Posterior PDF ...', end = " ")
    EI = qExpectedImprovement(
        model = single_model,
        best_f = best_observed_value
    )

    candidates, _ = optimize_acqf(
                                  acq_function = EI,
                                  bounds = bounds,
                                  q = n_points, # number or candidates to return
                                  num_restarts = CONSTANTS['restarts_number'],
                                  raw_samples = CONSTANTS['raw_samples'],
                                  # options = {"batch_limit": 5, "maxiter": 100}
                                  sequential = CONSTANTS['sequential']
                                 )
    print('[COMPLETED]')

    return candidates

# %%
CONSTANTS = {
    'iterations': 100,
    'initial_samples': 10,
    'restarts_number': 50,
    'raw_samples': 10,
    'candidates_num': 10,
    'sequential': True,
    'epsilon': 1,
    'radius': 1,
    'height': 10.5,
    'width': 6.6,
    'max_sensors': 15  
}

runningOnGoogleColab = False
    
if __name__ ==  '__main__':
    import sys

    if (runningOnGoogleColab == True):
        from google.colab import drive    
        drive.mount('/content/gdrive', force_remount=True)
        Data_path = 'gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/'
        sys.path.append('gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/')
        
    else:
        Data_path = '../../Codes/Sensor Simulator/'
        sys.path.append('../../Codes/Sensor Simulator/')

    # from ax import optimize, ChoiceParameter
    from scipy.stats import norm
    from numpy import argmax
    import SIM_SIS_Libraries.SensorsClass
    import SIM_SIS_Libraries.SIM_SIS_Simulator as sim_sis
    import SIM_SIS_Libraries.ParseFunctions as pf
    import itertools
    import numpy as np
    import pandas as pd
    import SIM_SIS_Libraries.PreDeploymentEvaluation as pde
    import copy
    from datetime import datetime
    import pytz
    import ast
    import os
    import random
    import plotly
    import torch

    from botorch.models import SingleTaskGP, ModelListGP
    from gpytorch.mlls.exact_marginal_log_likelihood import ExactMarginalLogLikelihood
    from botorch import fit_gpytorch_model
    from botorch.acquisition.monte_carlo import qExpectedImprovement
    from botorch.optim import optimize_acqf

    finalResults = []
    w = CONSTANTS['width'] - 0.5
    h = CONSTANTS['height'] - 0.5

    dataBoundaries = MakeDataBoundaries(
                                        height = CONSTANTS['height'], 
                                        width = CONSTANTS['width'], 
                                        MaxSensors = CONSTANTS['max_sensors']
                                       )

    BOV =  BOVariables(
                       Data_path, 
                       CONSTANTS['epsilon'], 
                       CONSTANTS['max_sensors'], 
                       CONSTANTS['max_sensors'], 
                       CONSTANTS['radius'],
                       CONSTANTS['initial_samples']
                      )


    print('----- Initializing Dataset... ', end = " ")
    train_x, train_y, best_observed_value = InitializeDataset(
                                                              BOV, 
                                                              init_num = CONSTANTS['initial_samples']
                                                             )
    
    print('[COMPLETED]')
    
    bounds = torch.tensor([[0.5] * CONSTANTS['max_sensors'] * 2, [w, h] * CONSTANTS['max_sensors']])

    for i in range(CONSTANTS['iterations']):
        print(f"Optimization iteration: {i + 1}")
        new_candidates = get_next_points(
                                         train_x, 
                                         train_y, 
                                         best_observed_value, 
                                         bounds, 
                                         n_points = CONSTANTS['candidates_num']
                                        )

        for index, candidate in enumerate(new_candidates):
            print('\t * Accuracy of candidate #', index + 1, ' is: ', end = " ")
            new_result = function_to_be_optimized(candidate)
            train_x = torch.cat([train_x, candidate.unsqueeze(0)])
            train_y = torch.cat([train_y, torch.stack([new_result])])
            print(new_result[0])

        best_observed_value = train_y.max().item()
        print(f"\n\tBest Point Performs: {best_observed_value}")
# Out:
# ----- Initializing Dataset...  [COMPLETED]
# Optimization iteration: 1
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-46834b138a71> in <module>
#      94
#      95         for candidate in new_candidates:
# ---> 96             print('\t * Accuracy of candidate #', index + 1, ' is: ', end = " ")
#      97             new_result = function_to_be_optimized(candidate)
#      98             train_x = torch.cat([train_x, candidate.unsqueeze(0)])
#
# NameError: name 'index' is not defined

# %%
bounds = torch.tensor([[0.5] * CONSTANTS['max_sensors'] * 2, [w, h] * CONSTANTS['max_sensors']])

for i in range(CONSTANTS['iterations']):
    print(f"Optimization iteration: {i + 1}")
    new_candidates = get_next_points(
                                     train_x, 
                                     train_y, 
                                     best_observed_value, 
                                     bounds, 
                                     n_points = CONSTANTS['candidates_num']
                                    )

    for index, candidate in enumerate(new_candidates):
        print('\t * Accuracy of candidate #', index + 1, ' is: ', end = " ")
        new_result = function_to_be_optimized(candidate)
        train_x = torch.cat([train_x, candidate.unsqueeze(0)])
        train_y = torch.cat([train_y, torch.stack([new_result])])
        print(new_result[0])

    best_observed_value = train_y.max().item()
    print(f"\n\tBest Point Performs: {best_observed_value}")
# Out:
# Optimization iteration: 1
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(46.1311)
# 	 * Accuracy of candidate # 2  is:  tensor(49.3048)
# 	 * Accuracy of candidate # 3  is:  tensor(48.9211)
# 	 * Accuracy of candidate # 4  is:  tensor(50.2965)
# 	 * Accuracy of candidate # 5  is:  tensor(53.3129)
# 	 * Accuracy of candidate # 6  is:  tensor(49.0656)
# 	 * Accuracy of candidate # 7  is:  tensor(49.1883)
# 	 * Accuracy of candidate # 8  is:  tensor(50.9979)
# 	 * Accuracy of candidate # 9  is:  tensor(52.0971)
# 	 * Accuracy of candidate # 10  is:  tensor(47.2093)
# 	 * Accuracy of candidate # 11  is:  tensor(47.2731)
# 	 * Accuracy of candidate # 12  is:  tensor(43.8084)
# 	 * Accuracy of candidate # 13  is:  tensor(53.6071)
# 	 * Accuracy of candidate # 14  is:  tensor(51.0258)
# 	 * Accuracy of candidate # 15  is:  tensor(51.9329)
# 	 * Accuracy of candidate # 16  is:  tensor(55.2068)
# 	 * Accuracy of candidate # 17  is:  tensor(42.1056)
# 	 * Accuracy of candidate # 18  is:  tensor(49.0368)
# 	 * Accuracy of candidate # 19  is:  tensor(46.9421)
# 	 * Accuracy of candidate # 20  is:  tensor(43.3221)
#
# 	Best Point Performs: 56.84663391113281
# Optimization iteration: 2
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(40.2992)
# 	 * Accuracy of candidate # 2  is:  tensor(41.1099)
# 	 * Accuracy of candidate # 3  is:  tensor(48.5231)
# 	 * Accuracy of candidate # 4  is:  tensor(51.4460)
# 	 * Accuracy of candidate # 5  is:  tensor(48.0507)
# 	 * Accuracy of candidate # 6  is:  tensor(44.4782)
# 	 * Accuracy of candidate # 7  is:  tensor(45.9462)
# 	 * Accuracy of candidate # 8  is:  tensor(50.2017)
# 	 * Accuracy of candidate # 9  is:  tensor(51.7958)
# 	 * Accuracy of candidate # 10  is:  tensor(56.8503)
# 	 * Accuracy of candidate # 11  is:  tensor(52.6146)
# 	 * Accuracy of candidate # 12  is:  tensor(43.3455)
# 	 * Accuracy of candidate # 13  is:  tensor(51.5393)
# 	 * Accuracy of candidate # 14  is:  tensor(41.5023)
# 	 * Accuracy of candidate # 15  is:  tensor(49.0086)
# 	 * Accuracy of candidate # 16  is:  tensor(52.9652)
# 	 * Accuracy of candidate # 17  is:  tensor(51.1699)
# 	 * Accuracy of candidate # 18  is:  tensor(49.8615)
# 	 * Accuracy of candidate # 19  is:  tensor(54.8168)
# 	 * Accuracy of candidate # 20  is:  tensor(51.0476)
#
# 	Best Point Performs: 56.85032272338867
# Optimization iteration: 3
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(56.8029)
# 	 * Accuracy of candidate # 2  is:  tensor(50.6655)
# 	 * Accuracy of candidate # 3  is:  tensor(38.7165)
# 	 * Accuracy of candidate # 4  is:  tensor(53.1858)
# 	 * Accuracy of candidate # 5  is:  tensor(50.9435)
# 	 * Accuracy of candidate # 6  is:  tensor(51.4466)
# 	 * Accuracy of candidate # 7  is:  tensor(48.9711)
# 	 * Accuracy of candidate # 8  is:  tensor(49.9712)
# 	 * Accuracy of candidate # 9  is:  tensor(46.6372)
# 	 * Accuracy of candidate # 10  is:  tensor(52.1832)
# 	 * Accuracy of candidate # 11  is:  tensor(62.4707)
# 	 * Accuracy of candidate # 12  is:  tensor(50.2096)
# 	 * Accuracy of candidate # 13  is:  tensor(53.9986)
# 	 * Accuracy of candidate # 14  is:  tensor(49.8160)
# 	 * Accuracy of candidate # 15  is:  tensor(46.4726)
# 	 * Accuracy of candidate # 16  is:  tensor(62.3208)
# 	 * Accuracy of candidate # 17  is:  tensor(51.3219)
# 	 * Accuracy of candidate # 18  is:  tensor(42.6931)
# 	 * Accuracy of candidate # 19  is:  tensor(55.7399)
# 	 * Accuracy of candidate # 20  is:  tensor(48.2477)
#
# 	Best Point Performs: 62.47074890136719
# Optimization iteration: 4
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(47.3092)
# 	 * Accuracy of candidate # 2  is:  tensor(42.2688)
# 	 * Accuracy of candidate # 3  is:  tensor(44.8293)
# 	 * Accuracy of candidate # 4  is:  tensor(44.0228)
# 	 * Accuracy of candidate # 5  is:  tensor(57.5690)
# 	 * Accuracy of candidate # 6  is:  tensor(54.4715)
# 	 * Accuracy of candidate # 7  is:  tensor(46.8721)
# 	 * Accuracy of candidate # 8  is:  tensor(46.4013)
# 	 * Accuracy of candidate # 9  is:  tensor(55.9070)
# 	 * Accuracy of candidate # 10  is:  tensor(51.3187)
# 	 * Accuracy of candidate # 11  is:  tensor(46.9220)
# 	 * Accuracy of candidate # 12  is:  tensor(48.9588)
# 	 * Accuracy of candidate # 13  is:  tensor(46.4874)
# 	 * Accuracy of candidate # 14  is:  tensor(54.1025)
# 	 * Accuracy of candidate # 15  is:  tensor(50.1507)
# 	 * Accuracy of candidate # 16  is:  tensor(54.4640)
# 	 * Accuracy of candidate # 17  is:  tensor(51.2098)
# 	 * Accuracy of candidate # 18  is:  tensor(48.5638)
# 	 * Accuracy of candidate # 19  is:  tensor(48.8721)
# 	 * Accuracy of candidate # 20  is:  tensor(44.3432)
#
# 	Best Point Performs: 62.47074890136719
# Optimization iteration: 5
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(47.1888)
# 	 * Accuracy of candidate # 2  is:  tensor(44.9781)
# 	 * Accuracy of candidate # 3  is:  tensor(49.2853)
# 	 * Accuracy of candidate # 4  is:  tensor(46.1573)
# 	 * Accuracy of candidate # 5  is:  tensor(52.0511)
# 	 * Accuracy of candidate # 6  is:  tensor(46.2131)
# 	 * Accuracy of candidate # 7  is:  tensor(45.8038)
# 	 * Accuracy of candidate # 8  is:  tensor(54.3829)
# 	 * Accuracy of candidate # 9  is:  tensor(44.2197)
# 	 * Accuracy of candidate # 10  is:  tensor(46.8017)
# 	 * Accuracy of candidate # 11  is:  tensor(48.6634)
# 	 * Accuracy of candidate # 12  is:  tensor(50.3281)
# 	 * Accuracy of candidate # 13  is:  tensor(44.7670)
# 	 * Accuracy of candidate # 14  is:  tensor(55.7551)
# 	 * Accuracy of candidate # 15  is:  tensor(43.9653)
# 	 * Accuracy of candidate # 16  is:  tensor(59.3399)
# 	 * Accuracy of candidate # 17  is:  tensor(46.8958)
# 	 * Accuracy of candidate # 18  is:  tensor(49.8215)
# 	 * Accuracy of candidate # 19  is:  tensor(47.0736)
# 	 * Accuracy of candidate # 20  is:  tensor(47.9560)
#
# 	Best Point Performs: 62.47074890136719
# Optimization iteration: 6
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(44.0171)
# 	 * Accuracy of candidate # 2  is:  tensor(46.7340)
# 	 * Accuracy of candidate # 3  is:  tensor(48.2969)
# 	 * Accuracy of candidate # 4  is:  tensor(48.7926)
# 	 * Accuracy of candidate # 5  is:  tensor(45.0750)
# 	 * Accuracy of candidate # 6  is:  tensor(43.5405)
# 	 * Accuracy of candidate # 7  is:  tensor(49.0442)
# 	 * Accuracy of candidate # 8  is:  tensor(45.1654)
# 	 * Accuracy of candidate # 9  is:  tensor(47.0792)
# 	 * Accuracy of candidate # 10  is:  tensor(45.7691)
# 	 * Accuracy of candidate # 11  is:  tensor(49.0599)
# 	 * Accuracy of candidate # 12  is:  tensor(44.8417)
# 	 * Accuracy of candidate # 13  is:  tensor(49.6516)
# 	 * Accuracy of candidate # 14  is:  tensor(44.2252)
# 	 * Accuracy of candidate # 15  is:  tensor(46.2658)
# 	 * Accuracy of candidate # 16  is:  tensor(49.7454)
# 	 * Accuracy of candidate # 17  is:  tensor(50.5801)
# 	 * Accuracy of candidate # 18  is:  tensor(51.6086)
# 	 * Accuracy of candidate # 19  is:  tensor(47.7389)
# 	 * Accuracy of candidate # 20  is:  tensor(56.1227)
#
# 	Best Point Performs: 62.47074890136719
# Optimization iteration: 7
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(47.1777)
# 	 * Accuracy of candidate # 2  is:  tensor(48.3348)
# 	 * Accuracy of candidate # 3  is:  tensor(43.2418)
# 	 * Accuracy of candidate # 4  is:  tensor(55.3138)
# 	 * Accuracy of candidate # 5  is:  tensor(48.6552)
# 	 * Accuracy of candidate # 6  is:  tensor(47.5747)
# 	 * Accuracy of candidate # 7  is:  tensor(49.6398)
# 	 * Accuracy of candidate # 8  is:  tensor(56.0339)
# 	 * Accuracy of candidate # 9  is:  tensor(47.7263)
# 	 * Accuracy of candidate # 10  is:  tensor(52.8544)
# 	 * Accuracy of candidate # 11  is:  tensor(48.7665)
# 	 * Accuracy of candidate # 12  is:  tensor(42.9313)
# 	 * Accuracy of candidate # 13  is:  tensor(43.5380)
# 	 * Accuracy of candidate # 14  is:  tensor(50.9933)
# 	 * Accuracy of candidate # 15  is:  tensor(46.8980)
# 	 * Accuracy of candidate # 16  is:  tensor(54.7378)
# 	 * Accuracy of candidate # 17  is:  tensor(40.3359)
# 	 * Accuracy of candidate # 18  is:  tensor(47.7934)
# 	 * Accuracy of candidate # 19  is:  tensor(48.0766)
# 	 * Accuracy of candidate # 20  is:  tensor(48.3111)
#
# 	Best Point Performs: 62.47074890136719
# Optimization iteration: 8
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(56.5789)
# 	 * Accuracy of candidate # 2  is:  tensor(49.7001)
# 	 * Accuracy of candidate # 3  is:  tensor(45.7611)
# 	 * Accuracy of candidate # 4  is:  tensor(46.9022)
# 	 * Accuracy of candidate # 5  is:  tensor(49.2293)
# 	 * Accuracy of candidate # 6  is:  tensor(49.5652)
# 	 * Accuracy of candidate # 7  is:  tensor(44.6601)
# 	 * Accuracy of candidate # 8  is:  tensor(48.0091)
# 	 * Accuracy of candidate # 9  is:  tensor(45.3962)
# 	 * Accuracy of candidate # 10  is:  tensor(48.5678)
# 	 * Accuracy of candidate # 11  is:  tensor(49.1271)
# 	 * Accuracy of candidate # 12  is:  tensor(46.7893)
# 	 * Accuracy of candidate # 13  is:  tensor(50.6878)
# 	 * Accuracy of candidate # 14  is:  tensor(51.0054)
# 	 * Accuracy of candidate # 15  is:  tensor(49.4078)
# 	 * Accuracy of candidate # 16  is:  tensor(43.5337)
# 	 * Accuracy of candidate # 17  is:  tensor(47.0787)
# 	 * Accuracy of candidate # 18  is:  tensor(44.9382)
# 	 * Accuracy of candidate # 19  is:  tensor(44.9064)
# 	 * Accuracy of candidate # 20  is:  tensor(47.5213)
#
# 	Best Point Performs: 62.47074890136719
# Optimization iteration: 9
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(49.5111)
# 	 * Accuracy of candidate # 2  is:  tensor(51.6454)
# 	 * Accuracy of candidate # 3  is:  tensor(55.0057)
# 	 * Accuracy of candidate # 4  is:  tensor(52.8176)
# 	 * Accuracy of candidate # 5  is:  tensor(49.0691)
# 	 * Accuracy of candidate # 6  is:  tensor(48.5275)
# 	 * Accuracy of candidate # 7  is:  tensor(45.9224)
# 	 * Accuracy of candidate # 8  is:  tensor(47.7101)
# 	 * Accuracy of candidate # 9  is:  tensor(48.4208)
# 	 * Accuracy of candidate # 10  is:  tensor(46.3781)
# 	 * Accuracy of candidate # 11  is:  tensor(45.6965)
# 	 * Accuracy of candidate # 12  is:  tensor(41.7021)
# 	 * Accuracy of candidate # 13  is:  tensor(46.3235)
# 	 * Accuracy of candidate # 14  is:  tensor(46.1962)
# 	 * Accuracy of candidate # 15  is:  tensor(46.8340)
# 	 * Accuracy of candidate # 16  is:  tensor(43.1325)
# 	 * Accuracy of candidate # 17  is:  tensor(44.6427)
# 	 * Accuracy of candidate # 18  is:  tensor(48.9242)
# 	 * Accuracy of candidate # 19  is:  tensor(41.0792)
# 	 * Accuracy of candidate # 20  is:  tensor(71.5026)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 10
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(45.0112)
# 	 * Accuracy of candidate # 2  is:  tensor(49.9794)
# 	 * Accuracy of candidate # 3  is:  tensor(42.8952)
# 	 * Accuracy of candidate # 4  is:  tensor(55.8575)
# 	 * Accuracy of candidate # 5  is:  tensor(49.4501)
# 	 * Accuracy of candidate # 6  is:  tensor(48.0933)
# 	 * Accuracy of candidate # 7  is:  tensor(51.9283)
# 	 * Accuracy of candidate # 8  is:  tensor(49.3879)
# 	 * Accuracy of candidate # 9  is:  tensor(43.6359)
# 	 * Accuracy of candidate # 10  is:  tensor(49.9054)
# 	 * Accuracy of candidate # 11  is:  tensor(47.9148)
# 	 * Accuracy of candidate # 12  is:  tensor(43.1248)
# 	 * Accuracy of candidate # 13  is:  tensor(46.6081)
# 	 * Accuracy of candidate # 14  is:  tensor(45.9661)
# 	 * Accuracy of candidate # 15  is:  tensor(50.7634)
# 	 * Accuracy of candidate # 16  is:  tensor(47.6670)
# 	 * Accuracy of candidate # 17  is:  tensor(40.6939)
# 	 * Accuracy of candidate # 18  is:  tensor(49.9597)
# 	 * Accuracy of candidate # 19  is:  tensor(46.6259)
# 	 * Accuracy of candidate # 20  is:  tensor(61.3920)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 11
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(56.7003)
# 	 * Accuracy of candidate # 2  is:  tensor(52.4638)
# 	 * Accuracy of candidate # 3  is:  tensor(47.8654)
# 	 * Accuracy of candidate # 4  is:  tensor(54.0828)
# 	 * Accuracy of candidate # 5  is:  tensor(46.8462)
# 	 * Accuracy of candidate # 6  is:  tensor(51.6678)
# 	 * Accuracy of candidate # 7  is:  tensor(49.3649)
# 	 * Accuracy of candidate # 8  is:  tensor(49.0088)
# 	 * Accuracy of candidate # 9  is:  tensor(50.8455)
# 	 * Accuracy of candidate # 10  is:  tensor(46.3551)
# 	 * Accuracy of candidate # 11  is:  tensor(47.3787)
# 	 * Accuracy of candidate # 12  is:  tensor(51.1083)
# 	 * Accuracy of candidate # 13  is:  tensor(47.4786)
# 	 * Accuracy of candidate # 14  is:  tensor(46.2608)
# 	 * Accuracy of candidate # 15  is:  tensor(43.5242)
# 	 * Accuracy of candidate # 16  is:  tensor(46.3639)
# 	 * Accuracy of candidate # 17  is:  tensor(52.5885)
# 	 * Accuracy of candidate # 18  is:  tensor(59.5908)
# 	 * Accuracy of candidate # 19  is:  tensor(48.0154)
# 	 * Accuracy of candidate # 20  is:  tensor(51.3085)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 12
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(46.0941)
# 	 * Accuracy of candidate # 2  is:  tensor(43.2497)
# 	 * Accuracy of candidate # 3  is:  tensor(44.2539)
# 	 * Accuracy of candidate # 4  is:  tensor(51.0064)
# 	 * Accuracy of candidate # 5  is:  tensor(43.4748)
# 	 * Accuracy of candidate # 6  is:  tensor(46.6152)
# 	 * Accuracy of candidate # 7  is:  tensor(47.9061)
# 	 * Accuracy of candidate # 8  is:  tensor(49.9922)
# 	 * Accuracy of candidate # 9  is:  tensor(49.2458)
# 	 * Accuracy of candidate # 10  is:  tensor(52.0380)
# 	 * Accuracy of candidate # 11  is:  tensor(42.6886)
# 	 * Accuracy of candidate # 12  is:  tensor(48.9461)
# 	 * Accuracy of candidate # 13  is:  tensor(53.9474)
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(47.0963)
# 	 * Accuracy of candidate # 2  is:  tensor(51.7426)
# 	 * Accuracy of candidate # 3  is:  tensor(54.9590)
# 	 * Accuracy of candidate # 4  is:  tensor(43.2451)
# 	 * Accuracy of candidate # 5  is:  tensor(50.4509)
# 	 * Accuracy of candidate # 6  is:  tensor(46.1193)
# 	 * Accuracy of candidate # 7  is:  tensor(61.5674)
# 	 * Accuracy of candidate # 8  is:  tensor(44.4482)
# 	 * Accuracy of candidate # 9  is:  tensor(48.3577)
# 	 * Accuracy of candidate # 10  is:  tensor(48.5110)
# 	 * Accuracy of candidate # 11  is:  tensor(42.8271)
# 	 * Accuracy of candidate # 12  is:  tensor(57.0224)
# 	 * Accuracy of candidate # 13  is:  tensor(52.6769)
# 	 * Accuracy of candidate # 14  is:  tensor(44.6156)
# 	 * Accuracy of candidate # 15  is:  tensor(47.0606)
# 	 * Accuracy of candidate # 16  is:  tensor(44.9748)
# 	 * Accuracy of candidate # 17  is:  tensor(49.7504)
# 	 * Accuracy of candidate # 18  is:  tensor(47.6087)
# 	 * Accuracy of candidate # 19  is:  tensor(48.7825)
# 	 * Accuracy of candidate # 20  is:  tensor(42.4487)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 16
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(48.1818)
# 	 * Accuracy of candidate # 2  is:  tensor(51.9151)
# 	 * Accuracy of candidate # 3  is:  tensor(42.2475)
# 	 * Accuracy of candidate # 4  is:  tensor(46.8860)
# 	 * Accuracy of candidate # 5  is:  tensor(48.9149)
# 	 * Accuracy of candidate # 6  is:  tensor(49.3926)
# 	 * Accuracy of candidate # 7  is:  tensor(45.1235)
# 	 * Accuracy of candidate # 8  is:  tensor(57.6698)
# 	 * Accuracy of candidate # 9  is:  tensor(43.4256)
# 	 * Accuracy of candidate # 10  is:  tensor(42.8096)
# 	 * Accuracy of candidate # 11  is:  tensor(41.7233)
# 	 * Accuracy of candidate # 12  is:  tensor(49.8004)
# 	 * Accuracy of candidate # 13  is:  tensor(47.2584)
# 	 * Accuracy of candidate # 14  is:  tensor(47.4825)
# 	 * Accuracy of candidate # 15  is:  tensor(46.5253)
# 	 * Accuracy of candidate # 16  is:  tensor(47.6263)
# 	 * Accuracy of candidate # 17  is:  tensor(48.4947)
# 	 * Accuracy of candidate # 18  is:  tensor(46.1434)
# 	 * Accuracy of candidate # 19  is:  tensor(47.5554)
# 	 * Accuracy of candidate # 20  is:  tensor(45.6955)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 17
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(48.3845)
# 	 * Accuracy of candidate # 2  is:  tensor(50.0276)
# 	 * Accuracy of candidate # 3  is:  tensor(54.0284)
# 	 * Accuracy of candidate # 4  is:  tensor(49.5234)
# 	 * Accuracy of candidate # 5  is:  tensor(56.3185)
# 	 * Accuracy of candidate # 6  is:  tensor(45.0601)
# 	 * Accuracy of candidate # 7  is:  tensor(58.3358)
# 	 * Accuracy of candidate # 8  is:  tensor(46.3947)
# 	 * Accuracy of candidate # 9  is:  tensor(43.8173)
# 	 * Accuracy of candidate # 10  is:  tensor(54.1235)
# 	 * Accuracy of candidate # 11  is:  tensor(47.1165)
# 	 * Accuracy of candidate # 12  is:  tensor(52.3837)
# 	 * Accuracy of candidate # 13  is:  tensor(44.7476)
# 	 * Accuracy of candidate # 14  is:  tensor(46.9830)
# 	 * Accuracy of candidate # 15  is:  tensor(53.0183)
# 	 * Accuracy of candidate # 16  is:  tensor(48.7171)
# 	 * Accuracy of candidate # 17  is:  tensor(52.6291)
# 	 * Accuracy of candidate # 18  is:  tensor(48.8676)
# 	 * Accuracy of candidate # 19  is:  tensor(46.2444)
# 	 * Accuracy of candidate # 20  is:  tensor(48.4804)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 18
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(42.7206)
# 	 * Accuracy of candidate # 2  is:  tensor(52.1984)
# 	 * Accuracy of candidate # 3  is:  tensor(56.1389)
# 	 * Accuracy of candidate # 4  is:  tensor(57.1507)
# 	 * Accuracy of candidate # 5  is:  tensor(46.0536)
# 	 * Accuracy of candidate # 6  is:  tensor(46.0476)
# 	 * Accuracy of candidate # 7  is:  tensor(50.5697)
# 	 * Accuracy of candidate # 8  is:  tensor(51.6590)
# 	 * Accuracy of candidate # 9  is:  tensor(52.2804)
# 	 * Accuracy of candidate # 10  is:  tensor(46.0697)
# 	 * Accuracy of candidate # 11  is:  tensor(50.2823)
# 	 * Accuracy of candidate # 12  is:  tensor(47.8616)
# 	 * Accuracy of candidate # 13  is:  tensor(43.6199)
# 	 * Accuracy of candidate # 14  is:  tensor(54.5745)
# 	 * Accuracy of candidate # 15  is:  tensor(49.5698)
# 	 * Accuracy of candidate # 16  is:  tensor(53.0746)
# 	 * Accuracy of candidate # 17  is:  tensor(40.1596)
# 	 * Accuracy of candidate # 18  is:  tensor(49.7309)
# 	 * Accuracy of candidate # 19  is:  tensor(46.3693)
# 	 * Accuracy of candidate # 20  is:  tensor(52.4928)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 19
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(48.4616)
# 	 * Accuracy of candidate # 2  is:  tensor(45.7209)
# 	 * Accuracy of candidate # 3  is:  tensor(50.3835)
# 	 * Accuracy of candidate # 4  is:  tensor(47.0182)
# 	 * Accuracy of candidate # 5  is:  tensor(45.4737)
# 	 * Accuracy of candidate # 6  is:  tensor(51.5980)
# 	 * Accuracy of candidate # 7  is:  tensor(48.8013)
# 	 * Accuracy of candidate # 8  is:  tensor(45.7471)
# 	 * Accuracy of candidate # 9  is:  tensor(61.9701)
# 	 * Accuracy of candidate # 10  is:  tensor(45.7648)
# 	 * Accuracy of candidate # 11  is:  tensor(44.7948)
# 	 * Accuracy of candidate # 12  is:  tensor(48.2225)
# 	 * Accuracy of candidate # 13  is:  tensor(46.9726)
# 	 * Accuracy of candidate # 14  is:  tensor(50.8993)
# 	 * Accuracy of candidate # 15  is:  tensor(52.1183)
# 	 * Accuracy of candidate # 16  is:  tensor(46.3602)
# 	 * Accuracy of candidate # 17  is:  tensor(45.9536)
# 	 * Accuracy of candidate # 18  is:  tensor(50.9190)
# 	 * Accuracy of candidate # 19  is:  tensor(48.2824)
# 	 * Accuracy of candidate # 20  is:  tensor(51.2162)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 20
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(48.3172)
# 	 * Accuracy of candidate # 2  is:  tensor(52.9169)
# 	 * Accuracy of candidate # 3  is:  tensor(54.6950)
# 	 * Accuracy of candidate # 4  is:  tensor(48.5603)
# 	 * Accuracy of candidate # 5  is:  tensor(49.5900)
# 	 * Accuracy of candidate # 6  is:  tensor(45.7741)
# 	 * Accuracy of candidate # 7  is:  tensor(42.1489)
# 	 * Accuracy of candidate # 8  is:  tensor(48.7104)
# 	 * Accuracy of candidate # 9  is:  tensor(45.2691)

#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 31
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(47.1130)
# 	 * Accuracy of candidate # 2  is:  tensor(50.6864)
# 	 * Accuracy of candidate # 3  is:  tensor(43.5055)
# 	 * Accuracy of candidate # 4  is:  tensor(45.0633)
# 	 * Accuracy of candidate # 5  is:  tensor(52.7870)
# 	 * Accuracy of candidate # 6  is:  tensor(43.0555)
# 	 * Accuracy of candidate # 7  is:  tensor(45.6854)
# 	 * Accuracy of candidate # 8  is:  tensor(46.6904)
# 	 * Accuracy of candidate # 9  is:  tensor(43.6577)
# 	 * Accuracy of candidate # 10  is:  tensor(52.4277)
# 	 * Accuracy of candidate # 11  is:  tensor(48.9499)
# 	 * Accuracy of candidate # 12  is:  tensor(48.9312)
# 	 * Accuracy of candidate # 13  is:  tensor(50.2603)
# 	 * Accuracy of candidate # 14  is:  tensor(46.1643)
# 	 * Accuracy of candidate # 15  is:  tensor(49.0808)
# 	 * Accuracy of candidate # 16  is:  tensor(44.0682)
# 	 * Accuracy of candidate # 17  is:  tensor(50.9997)
# 	 * Accuracy of candidate # 18  is:  tensor(56.0342)
# 	 * Accuracy of candidate # 19  is:  tensor(48.5865)
# 	 * Accuracy of candidate # 20  is:  tensor(48.7652)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 32
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(49.3936)
# 	 * Accuracy of candidate # 2  is:  tensor(53.7612)
# 	 * Accuracy of candidate # 3  is:  tensor(43.5060)
# 	 * Accuracy of candidate # 4  is:  tensor(58.3497)
# 	 * Accuracy of candidate # 5  is:  tensor(45.0209)
# 	 * Accuracy of candidate # 6  is:  tensor(48.1210)
# 	 * Accuracy of candidate # 7  is:  tensor(50.4528)
# 	 * Accuracy of candidate # 8  is:  tensor(50.8397)
# 	 * Accuracy of candidate # 9  is:  tensor(46.1293)
# 	 * Accuracy of candidate # 10  is:  tensor(44.1959)
# 	 * Accuracy of candidate # 11  is:  tensor(44.3864)
# 	 * Accuracy of candidate # 12  is:  tensor(45.1180)
# 	 * Accuracy of candidate # 13  is:  tensor(55.7959)
# 	 * Accuracy of candidate # 14  is:  tensor(56.6541)
# 	 * Accuracy of candidate # 15  is:  tensor(43.3694)
# 	 * Accuracy of candidate # 16  is:  tensor(52.8101)
# 	 * Accuracy of candidate # 17  is:  tensor(44.1638)
# 	 * Accuracy of candidate # 18  is:  tensor(50.7157)
# 	 * Accuracy of candidate # 19  is:  tensor(50.8297)
# 	 * Accuracy of candidate # 20  is:  tensor(57.4144)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 33
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(53.4951)
# 	 * Accuracy of candidate # 2  is:  tensor(49.5596)
# 	 * Accuracy of candidate # 3  is:  tensor(58.6711)
# 	 * Accuracy of candidate # 4  is:  tensor(46.8807)
# 	 * Accuracy of candidate # 5  is:  tensor(48.2727)
# 	 * Accuracy of candidate # 6  is:  tensor(47.7358)
# 	 * Accuracy of candidate # 7  is:  tensor(50.5461)
# 	 * Accuracy of candidate # 8  is:  tensor(49.6181)
# 	 * Accuracy of candidate # 9  is:  tensor(44.0569)
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(46.8789)
# 	 * Accuracy of candidate # 2  is:  tensor(44.1028)
# 	 * Accuracy of candidate # 3  is:  tensor(47.7984)
# 	 * Accuracy of candidate # 4  is:  tensor(44.2086)
# 	 * Accuracy of candidate # 5  is:  tensor(44.8792)
# 	 * Accuracy of candidate # 6  is:  tensor(50.1488)
# 	 * Accuracy of candidate # 7  is:  tensor(46.6803)
# 	 * Accuracy of candidate # 8  is:  tensor(54.7372)
# 	 * Accuracy of candidate # 9  is:  tensor(49.9282)
# 	 * Accuracy of candidate # 10  is:  tensor(44.6095)
# 	 * Accuracy of candidate # 11  is:  tensor(38.5816)
# 	 * Accuracy of candidate # 12  is:  tensor(44.4971)
# 	 * Accuracy of candidate # 13  is:  tensor(53.0509)
# 	 * Accuracy of candidate # 14  is:  tensor(47.5813)
# 	 * Accuracy of candidate # 15  is:  tensor(47.0105)
# 	 * Accuracy of candidate # 16  is:  tensor(47.6192)
# 	 * Accuracy of candidate # 17  is:  tensor(43.2448)
# 	 * Accuracy of candidate # 18  is:  tensor(49.3479)
# 	 * Accuracy of candidate # 19  is:  tensor(45.5956)
# 	 * Accuracy of candidate # 20  is:  tensor(49.9266)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 37
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(58.1910)
# 	 * Accuracy of candidate # 2  is:  tensor(50.1928)
# 	 * Accuracy of candidate # 3  is:  tensor(63.4067)
# 	 * Accuracy of candidate # 4  is:  tensor(46.5835)
# 	 * Accuracy of candidate # 5  is:  tensor(47.8682)
# 	 * Accuracy of candidate # 6  is:  tensor(53.9972)
# 	 * Accuracy of candidate # 7  is:  tensor(47.4339)
# 	 * Accuracy of candidate # 8  is:  tensor(49.5683)
# 	 * Accuracy of candidate # 9  is:  tensor(47.9464)
# 	 * Accuracy of candidate # 10  is:  tensor(43.5275)
# 	 * Accuracy of candidate # 11  is:  tensor(46.3876)
# 	 * Accuracy of candidate # 12  is:  tensor(45.1033)
# 	 * Accuracy of candidate # 13  is:  tensor(47.0004)
# 	 * Accuracy of candidate # 14  is:  tensor(49.3634)
# 	 * Accuracy of candidate # 15  is:  tensor(49.2313)
# 	 * Accuracy of candidate # 16  is:  tensor(63.1862)
# 	 * Accuracy of candidate # 17  is:  tensor(48.3239)
# 	 * Accuracy of candidate # 18  is:  tensor(53.3889)
# 	 * Accuracy of candidate # 19  is:  tensor(43.7610)
# 	 * Accuracy of candidate # 20  is:  tensor(52.9453)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 38
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(48.2554)
# 	 * Accuracy of candidate # 2  is:  tensor(51.9860)
# 	 * Accuracy of candidate # 3  is:  tensor(59.8466)
# 	 * Accuracy of candidate # 4  is:  tensor(48.9436)
# 	 * Accuracy of candidate # 5  is:  tensor(52.9735)
# 	 * Accuracy of candidate # 6  is:  tensor(40.0521)
# 	 * Accuracy of candidate # 7  is:  tensor(47.8684)
# 	 * Accuracy of candidate # 8  is:  tensor(40.7923)
# 	 * Accuracy of candidate # 9  is:  tensor(48.2954)
# 	 * Accuracy of candidate # 10  is:  tensor(42.8242)
# 	 * Accuracy of candidate # 11  is:  tensor(53.7463)
# 	 * Accuracy of candidate # 12  is:  tensor(49.2822)
# 	 * Accuracy of candidate # 13  is:  tensor(51.1183)
# 	 * Accuracy of candidate # 14  is:  tensor(45.4986)
# 	 * Accuracy of candidate # 15  is:  tensor(46.9786)
# 	 * Accuracy of candidate # 16  is:  tensor(50.4180)
# 	 * Accuracy of candidate # 17  is:  tensor(49.2341)
# 	 * Accuracy of candidate # 18  is:  tensor(53.9025)
# 	 * Accuracy of candidate # 19  is:  tensor(48.7155)
# 	 * Accuracy of candidate # 20  is:  tensor(50.0214)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 39
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(45.1844)
# 	 * Accuracy of candidate # 2  is:  tensor(47.8230)
# 	 * Accuracy of candidate # 3  is:  tensor(58.7025)
# 	 * Accuracy of candidate # 4  is:  tensor(43.7322)
# 	 * Accuracy of candidate # 5  is:  tensor(47.6619)
# 	 * Accuracy of candidate # 6  is:  tensor(50.4731)
# 	 * Accuracy of candidate # 7  is:  tensor(50.1047)
# 	 * Accuracy of candidate # 8  is:  tensor(49.3204)
# 	 * Accuracy of candidate # 9  is:  tensor(48.0235)
# 	 * Accuracy of candidate # 10  is:  tensor(40.9524)
# 	 * Accuracy of candidate # 11  is:  tensor(42.3338)
# 	 * Accuracy of candidate # 12  is:  tensor(47.9469)
# 	 * Accuracy of candidate # 13  is:  tensor(48.1861)
# 	 * Accuracy of candidate # 14  is:  tensor(49.4347)
# 	 * Accuracy of candidate # 15  is:  tensor(44.4793)
# 	 * Accuracy of candidate # 16  is:  tensor(45.9799)
# 	 * Accuracy of candidate # 17  is:  tensor(46.5350)
# 	 * Accuracy of candidate # 18  is:  tensor(41.9655)
# 	 * Accuracy of candidate # 19  is:  tensor(44.0581)
# 	 * Accuracy of candidate # 20  is:  tensor(51.4386)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 40
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(44.6829)
# 	 * Accuracy of candidate # 2  is:  tensor(47.1646)
# 	 * Accuracy of candidate # 3  is:  tensor(46.8710)
# 	 * Accuracy of candidate # 4  is:  tensor(48.2173)
# 	 * Accuracy of candidate # 5  is:  tensor(51.7872)
# 	 * Accuracy of candidate # 6  is:  tensor(51.4115)
# 	 * Accuracy of candidate # 7  is:  tensor(45.6301)
# 	 * Accuracy of candidate # 8  is:  tensor(56.4231)
# 	 * Accuracy of candidate # 9  is:  tensor(44.5098)
# 	 * Accuracy of candidate # 10  is:  tensor(47.5460)
# 	 * Accuracy of candidate # 11  is:  tensor(45.1270)
# 	 * Accuracy of candidate # 12  is:  tensor(55.8866)
# 	 * Accuracy of candidate # 13  is:  tensor(50.2973)
# 	 * Accuracy of candidate # 14  is:  tensor(43.6494)
# 	 * Accuracy of candidate # 15  is:  tensor(43.8258)
# 	 * Accuracy of candidate # 16  is:  tensor(52.7119)
# 	 * Accuracy of candidate # 17  is:  tensor(52.7519)
# 	 * Accuracy of candidate # 18  is:  tensor(50.6657)
# 	 * Accuracy of candidate # 19  is:  tensor(53.1204)
# 	 * Accuracy of candidate # 20  is:  tensor(50.5775)
#
# 	Best Point Performs: 71.50255584716797
# Optimization iteration: 41
# ...
# 	 * Accuracy of candidate # 3  is:  tensor(43.1661)
# 	 * Accuracy of candidate # 4  is:  tensor(44.0274)
# 	 * Accuracy of candidate # 5  is:  tensor(51.8060)
# 	 * Accuracy of candidate # 6  is:  tensor(49.6386)
# 	 * Accuracy of candidate # 7  is:  tensor(48.3917)
# 	 * Accuracy of candidate # 8  is:  tensor(51.6645)
# 	 * Accuracy of candidate # 9  is:  tensor(48.8996)
# 	 * Accuracy of candidate # 10  is:  tensor(47.0265)
# 	 * Accuracy of candidate # 11  is:  tensor(43.2855)
# 	 * Accuracy of candidate # 12  is:  tensor(47.3517)
# 	 * Accuracy of candidate # 13  is:  tensor(55.6253)
# 	 * Accuracy of candidate # 14  is:  tensor(47.9578)
# 	 * Accuracy of candidate # 15  is:  tensor(48.5429)
# 	 * Accuracy of candidate # 16  is:  tensor(48.8187)
# 	 * Accuracy of candidate # 17  is:  tensor(43.9697)
# 	 * Accuracy of candidate # 18  is:  tensor(52.2200)
# 	 * Accuracy of candidate # 19  is:  tensor(49.9226)
# 	 * Accuracy of candidate # 20  is:  tensor(52.3790)
#
# 	Best Point Performs: 73.07154846191406
# Optimization iteration: 72
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(49.9459)
# 	 * Accuracy of candidate # 2  is:  tensor(47.1050)
# 	 * Accuracy of candidate # 3  is:  tensor(50.0934)
# 	 * Accuracy of candidate # 4  is:  tensor(41.1357)
# 	 * Accuracy of candidate # 5  is:  tensor(52.0546)
# 	 * Accuracy of candidate # 6  is:  tensor(49.0471)
# 	 * Accuracy of candidate # 7  is:  tensor(41.5367)
# 	 * Accuracy of candidate # 8  is:  tensor(50.4899)
# 	 * Accuracy of candidate # 9  is:  tensor(59.2864)
# 	 * Accuracy of candidate # 10  is:  tensor(47.6944)
# 	 * Accuracy of candidate # 11  is:  tensor(48.5346)
# 	 * Accuracy of candidate # 12  is:  tensor(43.0113)
# 	 * Accuracy of candidate # 13  is:  tensor(47.2389)
# 	 * Accuracy of candidate # 14  is:  tensor(50.2012)
# 	 * Accuracy of candidate # 15  is:  tensor(48.9806)
# 	 * Accuracy of candidate # 16  is:  tensor(49.4872)
# 	 * Accuracy of candidate # 17  is:  tensor(57.5740)
# 	 * Accuracy of candidate # 18  is:  tensor(51.3485)
# 	 * Accuracy of candidate # 19  is:  tensor(49.3118)
# 	 * Accuracy of candidate # 20  is:  tensor(48.1838)
#
# 	Best Point Performs: 73.07154846191406
# Optimization iteration: 73
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(55.9508)
# 	 * Accuracy of candidate # 2  is:  tensor(45.6887)
# 	 * Accuracy of candidate # 3  is:  tensor(52.6505)
# 	 * Accuracy of candidate # 4  is:  tensor(53.4579)
# 	 * Accuracy of candidate # 5  is:  tensor(46.4967)
# 	 * Accuracy of candidate # 6  is:  tensor(50.3831)
# 	 * Accuracy of candidate # 7  is:  tensor(45.9906)
# 	 * Accuracy of candidate # 8  is:  tensor(43.5062)
# 	 * Accuracy of candidate # 9  is:  tensor(44.3817)
# 	 * Accuracy of candidate # 10  is:  tensor(44.5407)
# 	 * Accuracy of candidate # 11  is:  tensor(46.9236)
# 	 * Accuracy of candidate # 12  is:  tensor(40.9827)
# 	 * Accuracy of candidate # 13  is:  tensor(46.7790)
# 	 * Accuracy of candidate # 14  is:  tensor(47.8967)
# 	 * Accuracy of candidate # 15  is:  tensor(50.9502)
# 	 * Accuracy of candidate # 16  is:  tensor(41.7420)
# 	 * Accuracy of candidate # 17  is:  tensor(40.8620)
# 	 * Accuracy of candidate # 18  is:  tensor(47.7228)
# 	 * Accuracy of candidate # 19  is:  tensor(49.4439)
# 	 * Accuracy of candidate # 20  is:  tensor(45.1062)
#
# 	Best Point Performs: 73.07154846191406
# Optimization iteration: 74
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(47.9521)
# 	 * Accuracy of candidate # 2  is:  tensor(51.9740)
# 	 * Accuracy of candidate # 3  is:  tensor(42.1237)
# 	 * Accuracy of candidate # 4  is:  tensor(55.3919)
# 	 * Accuracy of candidate # 5  is:  tensor(50.9041)
# 	 * Accuracy of candidate # 6  is:  tensor(44.7112)
# 	 * Accuracy of candidate # 7  is:  tensor(46.4969)
# 	 * Accuracy of candidate # 8  is:  tensor(48.4984)
# 	 * Accuracy of candidate # 9  is:  tensor(46.4920)
# 	 * Accuracy of candidate # 10  is:  tensor(46.2725)
# 	 * Accuracy of candidate # 11  is:  tensor(58.0470)
# 	 * Accuracy of candidate # 12  is:  tensor(50.4958)
# 	 * Accuracy of candidate # 13  is:  tensor(46.3219)
# 	 * Accuracy of candidate # 14  is:  tensor(48.3139)
# 	 * Accuracy of candidate # 15  is:  tensor(45.7112)
# 	 * Accuracy of candidate # 16  is:  tensor(49.2811)
# 	 * Accuracy of candidate # 17  is:  tensor(47.6494)
# 	 * Accuracy of candidate # 18  is:  tensor(51.1270)
# 	 * Accuracy of candidate # 19  is:  tensor(51.2293)
# 	 * Accuracy of candidate # 20  is:  tensor(46.7368)
#
# 	Best Point Performs: 73.07154846191406
# Optimization iteration: 75
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(44.0320)
# 	 * Accuracy of candidate # 2  is:  tensor(52.7714)
# 	 * Accuracy of candidate # 3  is:  tensor(46.0716)
# 	 * Accuracy of candidate # 4  is:  tensor(43.2620)
# 	 * Accuracy of candidate # 5  is:  tensor(46.9120)
# 	 * Accuracy of candidate # 6  is:  tensor(48.3690)
# 	 * Accuracy of candidate # 7  is:  tensor(41.7343)
# 	 * Accuracy of candidate # 8  is:  tensor(49.5640)
# 	 * Accuracy of candidate # 9  is:  tensor(50.2561)
# 	 * Accuracy of candidate # 10  is:  tensor(44.1433)
# 	 * Accuracy of candidate # 11  is:  tensor(45.4563)
# 	 * Accuracy of candidate # 12  is:  tensor(49.3720)
# 	 * Accuracy of candidate # 13  is:  tensor(57.8606)
# 	 * Accuracy of candidate # 14  is:  tensor(51.0577)
# 	 * Accuracy of candidate # 15  is:  tensor(45.8467)
# 	 * Accuracy of candidate # 16  is:  tensor(42.5408)
# 	 * Accuracy of candidate # 17  is:  tensor(53.4594)
# 	 * Accuracy of candidate # 18  is:  tensor(47.3409)
# 	 * Accuracy of candidate # 19  is:  tensor(60.8794)
# 	 * Accuracy of candidate # 20  is:  tensor(50.0569)
#
# 	Best Point Performs: 73.07154846191406
# Optimization iteration: 76
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(51.2753)
# 	 * Accuracy of candidate # 2  is:  tensor(46.6670)
# 	 * Accuracy of candidate # 3  is:  tensor(47.2266)
# 	 * Accuracy of candidate # 4  is:  tensor(40.1841)
# 	 * Accuracy of candidate # 5  is:  tensor(62.1724)
# 	 * Accuracy of candidate # 6  is:  tensor(51.5740)
# 	 * Accuracy of candidate # 7  is:  tensor(46.1988)
# 	 * Accuracy of candidate # 8  is:  tensor(63.7232)
# 	 * Accuracy of candidate # 9  is:  tensor(44.7487)
# 	 * Accuracy of candidate # 10  is:  tensor(44.7183)
# 	 * Accuracy of candidate # 11  is:  tensor(49.9769)
# 	 * Accuracy of candidate # 12  is:  tensor(50.0508)
# 	 * Accuracy of candidate # 13  is:  tensor(47.4583)
# 	 * Accuracy of candidate # 14  is:  tensor(47.7578)
# 	 * Accuracy of candidate # 15  is:  tensor(47.1468)
# 	 * Accuracy of candidate # 16  is:  tensor(46.4603)
# 	 * Accuracy of candidate # 17  is:  tensor(58.6677)
# 	 * Accuracy of candidate # 18  is:  tensor(44.5375)
# 	 * Accuracy of candidate # 19  is:  tensor(43.2347)
# 	 * Accuracy of candidate # 20  is:  tensor(43.2533)
#
# 	Best Point Performs: 73.07154846191406
# Optimization iteration: 77
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(45.0841)
# 	 * Accuracy of candidate # 2  is:  tensor(53.8747)
# 	 * Accuracy of candidate # 3  is:  tensor(52.5344)
# 	 * Accuracy of candidate # 4  is:  tensor(51.5623)
# 	 * Accuracy of candidate # 5  is:  tensor(47.0083)
# 	 * Accuracy of candidate # 6  is:  tensor(46.1624)
# 	 * Accuracy of candidate # 7  is:  tensor(50.4592)
# 	 * Accuracy of candidate # 8  is:  tensor(44.7040)
# 	 * Accuracy of candidate # 9  is:  tensor(45.1601)
# 	 * Accuracy of candidate # 10  is:  tensor(45.5748)
# 	 * Accuracy of candidate # 11  is:  tensor(47.1540)
# 	 * Accuracy of candidate # 12  is:  tensor(48.4206)
# 	 * Accuracy of candidate # 13  is:  tensor(49.1047)
# 	 * Accuracy of candidate # 14  is:  tensor(48.0667)
# 	 * Accuracy of candidate # 15  is:  tensor(50.2658)
# 	 * Accuracy of candidate # 16  is:  tensor(50.8018)
# 	 * Accuracy of candidate # 17  is:  tensor(40.7436)
# 	 * Accuracy of candidate # 18  is:  tensor(47.7375)
# 	 * Accuracy of candidate # 19  is:  tensor(45.2301)
# 	 * Accuracy of candidate # 20  is:  tensor(51.2463)
#
# 	Best Point Performs: 73.07154846191406
# Optimization iteration: 78
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(56.4131)
# 	 * Accuracy of candidate # 2  is:  tensor(47.7473)
# 	 * Accuracy of candidate # 3  is:  tensor(52.2058)
# 	 * Accuracy of candidate # 4  is:  tensor(41.9423)
# 	 * Accuracy of candidate # 5  is:  tensor(56.4315)
# 	 * Accuracy of candidate # 6  is:  tensor(43.3795)
# 	 * Accuracy of candidate # 7  is:  tensor(42.2607)
# 	 * Accuracy of candidate # 8  is:  tensor(44.4464)
# 	 * Accuracy of candidate # 9  is:  tensor(51.9881)
# 	 * Accuracy of candidate # 10  is:  tensor(52.1352)
# 	 * Accuracy of candidate # 11  is:  tensor(47.5003)
# 	 * Accuracy of candidate # 12  is:  tensor(49.5789)
# 	 * Accuracy of candidate # 13  is:  tensor(52.6723)
# 	 * Accuracy of candidate # 14  is:  tensor(54.2147)
# 	 * Accuracy of candidate # 15  is:  tensor(49.6731)
# 	 * Accuracy of candidate # 16  is:  tensor(47.7603)
# 	 * Accuracy of candidate # 17  is:  tensor(49.6633)
# 	 * Accuracy of candidate # 18  is:  tensor(50.4944)
# 	 * Accuracy of candidate # 19  is:  tensor(47.8060)
# 	 * Accuracy of candidate # 20  is:  tensor(54.0907)
#
# 	Best Point Performs: 73.07154846191406
# Optimization iteration: 79
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(42.5456)
# 	 * Accuracy of candidate # 2  is:  tensor(49.0485)
# 	 * Accuracy of candidate # 3  is:  tensor(55.1941)
# 	 * Accuracy of candidate # 4  is:  tensor(49.2931)
# 	 * Accuracy of candidate # 5  is:  tensor(46.6752)
# 	 * Accuracy of candidate # 6  is:  tensor(45.3371)
# 	 * Accuracy of candidate # 7  is:  tensor(49.6871)
# 	 * Accuracy of candidate # 8  is:  tensor(41.4645)
# 	 * Accuracy of candidate # 9  is:  tensor(49.1097)
# 	 * Accuracy of candidate # 10  is:  tensor(48.5894)
# 	 * Accuracy of candidate # 11  is:  tensor(45.9353)
# 	 * Accuracy of candidate # 12  is:  tensor(56.3444)
# 	 * Accuracy of candidate # 13  is:  tensor(53.6004)
# 	 * Accuracy of candidate # 14  is:  tensor(47.4667)
# 	 * Accuracy of candidate # 15  is:  tensor(55.3386)
# 	 * Accuracy of candidate # 16  is:  tensor(46.8442)
# 	 * Accuracy of candidate # 17  is:  tensor(48.0729)
# 	 * Accuracy of candidate # 18  is:  tensor(51.1473)
# 	 * Accuracy of candidate # 19  is:  tensor(46.9797)
# 	 * Accuracy of candidate # 20  is:  tensor(45.8051)
#
# 	Best Point Performs: 73.07154846191406
# Optimization iteration: 80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-d31ae1104254> in <module>
#       3 for i in range(CONSTANTS['iterations']):
#       4     print(f"Optimization iteration: {i + 1}")
# ----> 5     new_candidates = get_next_points(
#       6                                      train_x,
#       7                                      train_y,
#
# <ipython-input-5-6d5197d8d8e2> in get_next_points(train_x, train_y, best_observed_value, bounds, n_points)
#     352     single_model = SingleTaskGP(train_x, train_y)
#     353     mll = ExactMarginalLogLikelihood(single_model.likelihood, single_model)
# --> 354     fit_gpytorch_model(mll)
#     355
#     356     print('----- Calculating Next Candidates Point From the Posterior PDF ...', end = " ")
#
# /usr/local/lib/python3.9/site-packages/botorch/fit.py in fit_gpytorch_model(mll, optimizer, **kwargs)
#     122                 mll.model.load_state_dict(original_state_dict)
#     123                 sample_all_priors(mll.model)
# --> 124             mll, _ = optimizer(mll, track_iterations=False, **kwargs)
#     125         has_optwarning = False
#     126         for w in ws:
#
# /usr/local/lib/python3.9/site-packages/botorch/optim/fit.py in fit_gpytorch_scipy(mll, bounds, method, options, track_iterations, approx_mll, scipy_objective, module_to_array_func, module_from_array_func)
#     237
#     238     with gpt_settings.fast_computations(log_prob=approx_mll):
# --> 239         res = minimize(
#     240             scipy_objective,
#     241             x0,
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     615                                   **options)
#     616     elif meth == 'l-bfgs-b':
# --> 617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# /usr/local/lib/python3.9/site-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# /usr/local/lib/python3.9/site-packages/botorch/optim/utils.py in _scipy_objective_and_grad(x, mll, property_dict)
#     219             return float("nan"), np.full_like(x, "nan")
#     220         raise e  # pragma: nocover
# --> 221     loss.backward()
#     222     param_dict = OrderedDict(mll.named_parameters())
#     223     grad = []
#
# /usr/local/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:
