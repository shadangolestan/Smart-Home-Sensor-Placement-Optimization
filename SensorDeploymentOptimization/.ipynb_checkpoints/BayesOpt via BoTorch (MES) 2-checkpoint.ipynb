# %%
# !pip3 install ax-platform
# !pip3 install botorch
# Out:
# Requirement already satisfied: ax-platform in /usr/local/lib/python3.9/site-packages (0.2.2)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.9/site-packages (from ax-platform) (2.13.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from ax-platform) (0.23.2)
# Requirement already satisfied: botorch==0.5.1 in /usr/local/lib/python3.9/site-packages (from ax-platform) (0.5.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/site-packages (from ax-platform) (4.14.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from ax-platform) (2.11.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch==0.5.1->ax-platform) (1.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: gpytorch>=1.5.1 in /usr/local/lib/python3.9/site-packages (from botorch==0.5.1->ax-platform) (1.5.1)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch==0.5.1->ax-platform) (1.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from ax-platform) (0.23.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.9/site-packages (from jinja2->ax-platform) (1.1.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (1.19.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (2020.4)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.9/site-packages (from plotly->ax-platform) (1.3.3)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages (from plotly->ax-platform) (1.15.0)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages (from plotly->ax-platform) (1.15.0)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages (from plotly->ax-platform) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from scikit-learn->ax-platform) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->ax-platform) (2.1.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (1.19.4)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (1.19.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from torch>=1.8.1->botorch==0.5.1->ax-platform) (3.10.0.2)
# Requirement already satisfied: botorch in /usr/local/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.4)
# Requirement already satisfied: gpytorch>=1.5.1 in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.1)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch) (1.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from gpytorch>=1.5.1->botorch) (0.23.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch) (1.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (1.19.4)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (1.19.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from torch>=1.8.1->botorch) (3.10.0.2)

# %%
class Data:
    def __init__(self, sensorPositions, space, epsilon):
        self.radius = 1
        self.placeHolders = sensorPositions
        self.epsilon = epsilon
        self.space = space
        # self.SensorPlaceHolderSetup()
        
    def frange(self, start, stop, step):
        steps = []
        while start <= stop:
            steps.append(start)
            start +=step
            
        return steps

    def GetSensorConfiguration(self):
        from collections import Counter
        sensorLocations, sensorTypes = self.GetSensorLocations()

        summaryDict = Counter(sensorTypes)

        # TODO: DIFFERENT SENSOR TYPE DEFINITIONS SHOULD BE ADDED HERE:
        configurationSummary = []
        for key in summaryDict:
            if (key == 1):
                configurationSummary.append(['motion sensors', summaryDict[key]])

            elif (key == 2):
                configurationSummary.append(['beacon sensors', summaryDict[key]])

        configurationDetails = []
        for index, loc in enumerate(sensorLocations):
            if (sensorTypes[index] == 1):
                configurationDetails.append(tuple([loc, 'kitchen', 'motion sensors']))

            elif (sensorTypes[index] == 2):
                configurationDetails.append(tuple([loc, 'kitchen', 'beacon sensors']))

        return [[configurationSummary, [tuple(configurationDetails)]], self.radius]


    def GetSensorLocations(self):
        sensorLocations = []
        sensorTypes = []
        for index, sensorIndicator in enumerate(self.placeHolders):
            sensorLocations.append(self.placeHolders[index])

            # TODO: DIFFERENT SENSOR TYPE DEFINITIONS SHOULD BE ADDED HERE:
            sensorTypes.append(1)


        return sensorLocations, sensorTypes


class BOVariables:
    def __init__(self, Data_path, epsilon, initSensorNum, maxSensorNum, radius, sampleSize):
        self.epsilon = epsilon
        self.Data_path = Data_path
        self.initSensorNum = initSensorNum
        self.maxSensorNum = maxSensorNum
        self.radius = radius
        self.sensor_distribution, self.types, self.space, self.rooms, self.agentTraces = self.ModelsInitializations()

    def ModelsInitializations(self):
        #----- Space and agent models -----: 
        simworldname = self.Data_path + '/Configuration Files/simulationWorld2.xml'
        agentTraces = []
        directory = os.fsencode(self.Data_path + 'Agent Trace Files2/')
            
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.endswith(".csv"): 
                agentTraces.append(self.Data_path + 'Agent Trace Files2/' + filename)

        # Parsing the space model: 
        space, rooms = pf.ParseWorld(simworldname)

        xs = []
        for i in space:
          for j in i:
            xs.append(j)
        A = list(set(xs))
        A.sort()
        space = [A[-1], A[-2]]

        # User parameters 
        types, sensor_distribution = pf.GetUsersParameters()

        roomsList = []
        for room in sensor_distribution:
            roomsList.append(room)
              
        return sensor_distribution, types, space, rooms, agentTraces


def frange(start, stop, step):
    steps = []
    while start <= stop:
        steps.append(start)
        start +=step
        
    return steps

def MakeSensorCombinations(start, end, epsilon, sensorType, room):
    a1, b1 = makeBoundaries(epsilon, start[0], end[0])
    a2, b2 = makeBoundaries(epsilon, start[1], end[1])    
    Xs = frange(a1, b1, epsilon)
    Ys = frange(a2, b2, epsilon)
    
    points = list(itertools.product(list(itertools.product(Xs, Ys)), [room], [sensorType[0]])) 
    C = itertools.combinations(points, distribution[room][types.index(sensorType)])

    return C

def PreProcessor(df):
    df['motion sensors'] = df['motion sensors'].apply(lambda s: list(map(int, s)))
    try:
      df['beacon sensors'] = df['beacon sensors'].apply(lambda s: list(map(int, s)))
    except:
      pass

    sensors = set([])

    previous_M = None
    previous_B = None
    output_file = []

    for index, row in df.iterrows():
      T = row['time']
      M = row['motion sensors']
      try:
        B = row['beacon sensors']
      except:
        pass

      Activity = row['activity']
      Activity = Activity.replace(' ', '_')
      MotionSensor_Names = []
      sensorNames = []
      MotionSensor_Message = []
      BeaconSensor_Names = []
      BeaconSensor_Message = []
      

      # time = convertTime(T)
      time = "2020-06-16 " + T + ".00"

      # Motion Sensor
      for i in range(len(M)):
        sensorNames.append(Name(i, 'M'))
        if M[i] == 1:
          if (previous_M != None):
            if (previous_M[i] == 0):
              MotionSensor_Names.append(Name(i,'M'))
              MotionSensor_Message.append('ON')

          else:
            MotionSensor_Names.append(Name(i,'M'))
            MotionSensor_Message.append('ON')

        if previous_M != None:
          if M[i] == 0 and previous_M[i] == 1:
            MotionSensor_Names.append(Name(i,'M'))
            MotionSensor_Message.append('OFF')

      previous_M = M
      # Beacon Sensor

      try:
        for i in range(len(B)):
          sensorNames.append(Name(i, 'B'))
          if B[i] == 1:
            BeaconSensor_Names.append(Name(i,'B'))
            BeaconSensor_Message.append('ON')
          if previous_B != None:
            if B[i] == 0 and previous_B[i] == 1: 
              BeaconSensor_Names.append(Name(i,'B'))
              BeaconSensor_Message.append('OFF')
        previous_B = B

      except:
        pass

      for m in range(len(MotionSensor_Names)):
        output_file.append(time +' '+ MotionSensor_Names[m] + ' ' + MotionSensor_Names[m] + ' ' + MotionSensor_Message[m] + ' ' + Activity)
        
      for s in sensorNames:
          sensors.add(s)

    return output_file, list(sensors)

#returns the name of the sensor
def Name(number, typeSensor):
    if number < 10:
      return typeSensor + str(0) + str(number)
    else:
      return typeSensor + str(number)

#converts epoch time to human readable
def convertTime(posix_timestamp):
    tz = pytz.timezone('MST')
    dt = datetime.fromtimestamp(posix_timestamp, tz)
    time = dt.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
    return time

def MakeDataBoundaries(height = 10.5, width = 6.6, MaxSensors = 15):
    from collections import defaultdict, OrderedDict

    d = dict()

    for idx in range(MaxSensors):
            d['x' + str(idx)] = (0.5, width - 0.5)
            d['y' + str(idx)] = (0.5, height - 0.5)

    return d

def black_box_function(sample, simulateMotionSensors = True, simulateEstimotes = False, Plotting = False):       
    files = []

    if (runningOnGoogleColab == True):
        sys.path.append('gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/')
        Data_path = 'gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/'
        
    else:
        sys.path.append('../../Codes/Sensor Simulator/')
        Data_path = '../../Codes/Sensor Simulator/'

    all_sensors = set([])

    for agentTrace in BOV.agentTraces:
        df_ = sim_sis.RunSimulator(BOV.space, BOV.rooms, agentTrace, sample.GetSensorConfiguration(), simulateMotionSensors, simulateEstimotes, Plotting, BOV.Data_path)
        dataFile, sensors = PreProcessor(df_)
        all_sensors.update(sensors)
        files.append(dataFile)
        
    
    if (runningOnGoogleColab == True):
        sys.path.append('gdrive/My Drive/PhD/Thesis/Ideas/Codes/CASAS/AL-Smarthome')

    else:
        sys.path.append('../../Codes/CASAS/AL-Smarthome')

    import al
    import imp
    imp.reload(al)
    all_sensors = list(all_sensors)

    accuracy = (al.leave_one_out(files, all_sensors)[0]) * 100

    if accuracy < 0:
        accuracy = 0

    return [accuracy]

def function_to_be_optimized(T):
    sensorPositions = []
    sensor_xy = []
    for i, item in enumerate(T):
            if i % 2 == 0:
                sensor_xy.append(item)

            else:
                sensor_xy.append(item)  
                sensorPositions.append(sensor_xy)
                sensor_xy = []

    data = Data(sensorPositions, BOV.space, CONSTANTS['epsilon'])
    return torch.Tensor(black_box_function(data))

def InitializeDataset(BOV, init_num = 5):
    train_x = []
    for i in range(init_num):
        Xs = frange(0, BOV.space[0], BOV.epsilon)
        Ys = frange(0, BOV.space[1], BOV.epsilon)
        grid = np.zeros(len(Xs) * len(Ys)).tolist()
        placeHolders = []


        for x in Xs:
            for y in Ys:
                placeHolders.append([x, y])

        i = 0
        while i < BOV.initSensorNum:
            cell = random.randrange(len(grid))
            if grid[cell] == 0:
                grid[cell] = 1
                i += 1

        sensorPositions = []
        sensorTypes = []
        for index, sensorIndicator in enumerate(grid):
            if (sensorIndicator > 0):
                # sensorPositions.append(torch.Tensor(placeHolders[index]))
                sensorPositions.append(placeHolders[index][0])
                sensorPositions.append(placeHolders[index][1])
                sensorTypes.append(torch.Tensor(sensorIndicator))


        sensorPositions = torch.Tensor(sensorPositions)


        # data = Data(sensorPositions, BOV.space, CONSTANTS['epsilon'])
        train_x.append(sensorPositions)

    train_x = torch.stack(train_x)

    train_y = []

    sensorPositions = []
    sensor_xy = []
    for T in train_x:

        for i, item in enumerate(T):
            if i % 2 == 0:
                sensor_xy.append(item)

            else:
                sensor_xy.append(item)  
                sensorPositions.append(sensor_xy)
                sensor_xy = []

        data = Data(sensorPositions, BOV.space, CONSTANTS['epsilon'])
        train_y.append(torch.Tensor(black_box_function(data)))

    train_y = torch.stack(train_y)
    best_observed_value = train_y.max()

    return train_x, train_y, best_observed_value
    

def frange(start, stop, step):
    steps = []
    while start <= stop:
        steps.append(start)
        start +=step
        
    return steps

def get_next_points(train_x, train_y, best_observed_value, bounds, n_points = 10):
    single_model = SingleTaskGP(train_x, train_y)
    mll = ExactMarginalLogLikelihood(single_model.likelihood, single_model)
    fit_gpytorch_model(mll)
    
    print('----- Calculating Next Candidates Point From the Posterior PDF ...', end = " ")
    MES = qMaxValueEntropy(
                           model = single_model,
                           best_f = best_observed_value,
                           candidate_set = train_x
                          )
    

    candidates, _ = optimize_acqf(
                                  acq_function = MES,
                                  bounds = bounds,
                                  q = n_points, # number or candidates to return
                                  num_restarts = CONSTANTS['restarts_number'],
                                  raw_samples = CONSTANTS['raw_samples'],
                                  # options = {"batch_limit": 5, "maxiter": 100}
                                  sequential = CONSTANTS['sequential']
                                 )
    print('[COMPLETED]')

    return candidates

# %%
CONSTANTS = {
    'iterations': 100,
    'initial_samples': 30,
    'restarts_number': 15,
    'raw_samples': 15,
    'candidates_num': 20,
    'sequential': True,
    'epsilon': 1,
    'radius': 1,
    'height': 10.5,
    'width': 6.6,
    'max_sensors': 15  
}

global runningOnGoogleColab
runningOnGoogleColab = False
    
if __name__ ==  '__main__':
    import sys

    if (runningOnGoogleColab == True):
        from google.colab import drive    
        drive.mount('/content/gdrive', force_remount=True)
        Data_path = 'gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/'
        sys.path.append('gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/')
        
    else:
        Data_path = '../../Codes/Sensor Simulator/'
        sys.path.append('../../Codes/Sensor Simulator/')

    # from ax import optimize, ChoiceParameter
    from scipy.stats import norm
    from numpy import argmax
    import SIM_SIS_Libraries.SensorsClass
    import SIM_SIS_Libraries.SIM_SIS_Simulator as sim_sis
    import SIM_SIS_Libraries.ParseFunctions as pf
    import itertools
    import numpy as np
    import pandas as pd
    import SIM_SIS_Libraries.PreDeploymentEvaluation as pde
    import copy
    from datetime import datetime
    import pytz
    import ast
    import os
    import random
    import plotly
    import torch

    from botorch.models import SingleTaskGP, ModelListGP
    from gpytorch.mlls.exact_marginal_log_likelihood import ExactMarginalLogLikelihood
    from botorch import fit_gpytorch_model
    from botorch.acquisition.max_value_entropy_search import qMaxValueEntropy
    from botorch.optim import optimize_acqf

    # epsilon = 1
    # radius = 1
    finalResults = []
    # height = 10.5
    # width = 6.6
    # MaxSensors = 15
    w = CONSTANTS['width'] - 0.5
    h = CONSTANTS['height'] - 0.5
    # n_runs = 100
    # init_num = 10

    dataBoundaries = MakeDataBoundaries(
                                        height = CONSTANTS['height'], 
                                        width = CONSTANTS['width'], 
                                        MaxSensors = CONSTANTS['max_sensors']
                                       )

    BOV =  BOVariables(
                       Data_path, 
                       CONSTANTS['epsilon'], 
                       CONSTANTS['max_sensors'], 
                       CONSTANTS['max_sensors'], 
                       CONSTANTS['radius'],
                       CONSTANTS['initial_samples']
                      )
    
    print('----- Initializing Dataset... ', end = " ")
    train_x, train_y, best_observed_value = InitializeDataset(
                                                              BOV, 
                                                              init_num = CONSTANTS['initial_samples']
                                                             )
    
    print('[COMPLETED]')
    
    bounds = torch.tensor([[0.5] * CONSTANTS['max_sensors'] * 2, [w, h] * CONSTANTS['max_sensors']])

    for i in range(CONSTANTS['iterations']):
        print(f"Optimization iteration: {i + 1}")
        new_candidates = get_next_points(
                                         train_x, 
                                         train_y, 
                                         best_observed_value, 
                                         bounds, 
                                         n_points = CONSTANTS['candidates_num']
                                        )
        
        for index, candidate in enumerate(new_candidates):
            print('\t * Accuracy of candidate #', index + 1, ' is: ', end = " ")
            new_result = function_to_be_optimized(candidate)
            train_x = torch.cat([train_x, candidate.unsqueeze(0)])
            train_y = torch.cat([train_y, torch.stack([new_result])])
            print(new_result[0])

        best_observed_value = train_y.max().item()
        print(f"Best Point Performs: {best_observed_value}")
# Out:
# ----- Initializing Dataset...  [COMPLETED]
# Optimization iteration: 1
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(50

#
# 	Best Point Performs: 63.97031021118164
# Optimization iteration: 14
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(49.7342)
# 	 * Accuracy of candidate # 2  is:  tensor(45.7708)
# 	 * Accuracy of candidate # 3  is:  tensor(40.9101)
# 	 * Accuracy of candidate # 4  is:  tensor(41.8473)
# 	 * Accuracy of candidate # 5  is:  tensor(42.0325)
# 	 * Accuracy of candidate # 6  is:  tensor(48.6480)
# 	 * Accuracy of candidate # 7  is:  tensor(49.1560)
# 	 * Accuracy of candidate # 8  is:  tensor(47.0978)
# 	 * Accuracy of candidate # 9  is:  tensor(48.7858)
# 	 * Accuracy of candidate # 10  is:  tensor(47.1303)
# 	 * Accuracy of candidate # 11  is:  tensor(42.4457)
# 	 * Accuracy of candidate # 12  is:  tensor(46.9264)
# 	 * Accuracy of candidate # 13  is:  tensor(52.2244)
# 	 * Accuracy of candidate # 14  is:  tensor(47.5201)
# 	 * Accuracy of candidate # 15  is:  tensor(51.5719)
# 	 * Accuracy of candidate # 16  is:  tensor(48.8823)
# 	 * Accuracy of candidate # 17  is:  tensor(51.0433)
# 	 * Accuracy of candidate # 18  is:  tensor(46.3989)
# 	 * Accuracy of candidate # 19  is:  tensor(59.0781)
# 	 * Accuracy of candidate # 20  is:  tensor(52.9828)
#
# 	Best Point Performs: 63.97031021118164
# Optimization iteration: 15
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(43.4076)
# 	 * Accuracy of candidate # 2  is:  tensor(50.7450)
# 	 * Accuracy of candidate # 3  is:  tensor(44.3012)
# 	 * Accuracy of candidate # 4  is:  tensor(49.2393)
# 	 * Accuracy of candidate # 5  is:  tensor(53.1119)
# 	 * Accuracy of candidate # 6  is:  tensor(51.7394)
# 	 * Accuracy of candidate # 7  is:  tensor(49.5336)
# 	 * Accuracy of candidate # 8  is:  tensor(50.6835)
# 	 * Accuracy of candidate # 9  is:  tensor(54.9213)
# 	 * Accuracy of candidate # 10  is:  tensor(43.5921)
# 	 * Accuracy of candidate # 11  is:  tensor(46.1857)
# 	 * Accuracy of candidate # 12  is:  tensor(45.4074)
# 	 * Accuracy of candidate # 13  is:  tensor(44.4492)
# 	 * Accuracy of candidate # 14  is:  tensor(45.5630)
# 	 * Accuracy of candidate # 15  is:  tensor(54.4952)
# 	 * Accuracy of candidate # 16  is:  tensor(51.7638)
# 	 * Accuracy of candidate # 17  is:  tensor(49.9395)
# 	 * Accuracy of candidate # 18  is:  tensor(45.4200)
# 	 * Accuracy of candidate # 19  is:  tensor(47.9081)
# 	 * Accuracy of candidate # 20  is:  tensor(44.4395)
#
# 	Best Point Performs: 63.97031021118164
# Optimization iteration: 16
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(50.4561)
# 	 * Accuracy of candidate # 2  is:  tensor(57.5382)
# 	 * Accuracy of candidate # 3  is:  tensor(50.7668)
# 	 * Accuracy of candidate # 4  is:  tensor(61.3868)
# 	 * Accuracy of candidate # 5  is:  tensor(50.8717)
# 	 * Accuracy of candidate # 6  is:  tensor(49.9587)
# 	 * Accuracy of candidate # 7  is:  tensor(44.5254)

#
# 	Best Point Performs: 69.53235626220703
# Optimization iteration: 24
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(48.1611)
# 	 * Accuracy of candidate # 2  is:  tensor(52.1945)
# 	 * Accuracy of candidate # 3  is:  tensor(49.1667)
# 	 * Accuracy of candidate # 4  is:  tensor(42.9678)
# 	 * Accuracy of candidate # 5  is:  tensor(48.9509)
# 	 * Accuracy of candidate # 6  is:  tensor(44.0276)
# 	 * Accuracy of candidate # 7  is:  tensor(52.8986)
# 	 * Accuracy of candidate # 8  is:  tensor(45.1130)
# 	 * Accuracy of candidate # 9  is:  tensor(46.7669)
# 	 * Accuracy of candidate # 10  is:  tensor(45.0152)
# 	 * Accuracy of candidate # 11  is:  tensor(45.3247)
# 	 * Accuracy of candidate # 12  is:  tensor(50.3212)
# 	 * Accuracy of candidate # 13  is:  tensor(41.6943)
# 	 * Accuracy of candidate # 14  is:  tensor(55.5913)
# 	 * Accuracy of candidate # 15  is:  tensor(49.1058)
# 	 * Accuracy of candidate # 16  is:  tensor(45.1682)
# 	 * Accuracy of candidate # 17  is:  tensor(46.9020)
# 	 * Accuracy of candidate # 18  is:  tensor(50.0300)
# 	 * Accuracy of candidate # 19  is:  tensor(53.3561)
# 	 * Accuracy of candidate # 20  is:  tensor(51.7693)
#
# 	Best Point Performs: 69.53235626220703
# Optimization iteration: 25
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(50.3311)
# 	 * Accuracy of candidate # 2  is:  tensor(50.9471)
# 	 * Accuracy of candidate # 3  is:  tensor(53.4229)
# 	 * Accuracy of candidate # 4  is:  tensor(41.9445)
# 	 * Accuracy of candidate # 5  is:  tensor(46.5132)
# 	 * Accuracy of candidate # 6  is:  tensor(49.9833)
# 	 * Accuracy of candidate # 7  is:  tensor(41.1026)
# 	 * Accuracy of candidate # 8  is:  tensor(40.3621)
# 	 * Accuracy of candidate # 9  is:  tensor(47.7702)
# 	 * Accuracy of candidate # 10  is:  tensor(49.2451)
# 	 * Accuracy of candidate # 11  is:  tensor(54.9333)
# 	 * Accuracy of candidate # 12  is:  tensor(46.7336)
# 	 * Accuracy of candidate # 13  is:  tensor(44.9201)
# 	 * Accuracy of candidate # 14  is:  tensor(47.6078)
# 	 * Accuracy of candidate # 15  is:  tensor(46.1884)
# 	 * Accuracy of candidate # 16  is:  tensor(50.3713)
# 	 * Accuracy of candidate # 17  is:  tensor(62.3698)
# 	 * Accuracy of candidate # 18  is:  tensor(42.7836)
# 	 * Accuracy of candidate # 19  is:  tensor(55.5305)
# 	 * Accuracy of candidate # 20  is:  tensor(47.5526)
#
# 	Best Point Performs: 69.53235626220703
# Optimization iteration: 26
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(55.9071)
# 	 * Accuracy of candidate # 2  is:  tensor(44.0652)
# 	 * Accuracy of candidate # 3  is:  tensor(54.0730)
# 	 * Accuracy of candidate # 4  is:  tensor(57.0415)
# 	 * Accuracy of candidate # 5  is:  tensor(51.0502)
# 	 * Accuracy of candidate # 6  is:  tensor(47.4177)
# 	 * Accuracy of candidate # 7  is:  tensor(54.7454)
# 	 * Accuracy of candidate # 8  is:  tensor(47.9302)
# 	 * Accuracy of candidate # 9  is:  tensor(49.9680)
# 	 * Accuracy of candidate # 10  is:  tensor(46.0317)
# 	 * Accuracy of candidate # 11  is:  tensor(46.9819)
# 	 * Accuracy of candidate # 8  is:  tensor(48.6798)
# 	 * Accuracy of candidate # 9  is:  tensor(45.9021)
# 	 * Accuracy of candidate # 10  is:  tensor(52.3679)
# 	 * Accuracy of candidate # 11  is:  tensor(51.7393)
# 	 * Accuracy of candidate # 12  is:  tensor(47.6839)
# 	 * Accuracy of candidate # 13  is:  tensor(44.3132)
# 	 * Accuracy of candidate # 14  is:  tensor(52.2199)
# 	 * Accuracy of candidate # 15  is:  tensor(43.4871)
# 	 * Accuracy of candidate # 16  is:  tensor(53.2520)
# 	 * Accuracy of candidate # 17  is:  tensor(50.4189)
# 	 * Accuracy of candidate # 18  is:  tensor(47.6369)
# 	 * Accuracy of candidate # 19  is:  tensor(57.7395)
# 	 * Accuracy of candidate # 20  is:  tensor(51.8082)
#
# 	Best Point Performs: 69.53235626220703
# Optimization iteration: 40
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(50.7103)
# 	 * Accuracy of candidate # 2  is:  tensor(43.7217)
# 	 * Accuracy of candidate # 3  is:  tensor(59.5457)
# 	 * Accuracy of candidate # 4  is:  tensor(40.8911)
# 	 * Accuracy of candidate # 5  is:  tensor(48.0649)
# 	 * Accuracy of candidate # 6  is:  tensor(55.4326)
# 	 * Accuracy of candidate # 7  is:  tensor(54.1945)
# 	 * Accuracy of candidate # 8  is:  tensor(44.1019)
# 	 * Accuracy of candidate # 9  is:  tensor(54.2970)
# 	 * Accuracy of candidate # 10  is:  tensor(50.8811)
# 	 * Accuracy of candidate # 11  is:  tensor(45.8163)
# 	 * Accuracy of candidate # 12  is:  tensor(45.7785)
# 	 * Accuracy of candidate # 13  is:  tensor(44.4106)
# 	 * Accuracy of candidate # 14  is:  tensor(49.2932)
# 	 * Accuracy of candidate # 15  is:  tensor(42.9788)
# 	 * Accuracy of candidate # 16  is:  tensor(45.1238)
# 	 * Accuracy of candidate # 17  is:  tensor(45.8898)
# 	 * Accuracy of candidate # 18  is:  tensor(45.0281)
# 	 * Accuracy of candidate # 19  is:  tensor(50.1365)
# 	 * Accuracy of candidate # 20  is:  tensor(53.2034)
#
# 	Best Point Performs: 69.53235626220703
# Optimization iteration: 41
# ...
# 	 * Accuracy of candidate # 19  is:  tensor(46.8240)
# 	 * Accuracy of candidate # 20  is:  tensor(41.9440)
#
# 	Best Point Performs: 71.13964080810547
# Optimization iteration: 47
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(50.4212)
# 	 * Accuracy of candidate # 2  is:  tensor(51.1431)
# 	 * Accuracy of candidate # 3  is:  tensor(60.1938)
# 	 * Accuracy of candidate # 4  is:  tensor(45.6494)
# 	 * Accuracy of candidate # 5  is:  tensor(39.4662)
# 	 * Accuracy of candidate # 6  is:  tensor(48.9997)
# 	 * Accuracy of candidate # 7  is:  tensor(49.3473)
# 	 * Accuracy of candidate # 8  is:  tensor(56.2146)
# 	 * Accuracy of candidate # 9  is:  tensor(44.5578)
# 	 * Accuracy of candidate # 10  is:  tensor(45.3375)
# 	 * Accuracy of candidate # 11  is:  tensor(41.1068)
# 	 * Accuracy of candidate # 12  is:  tensor(49.7791)
# 	 * Accuracy of candidate # 13  is:  tensor(50.7489)
# 	 * Accuracy of candidate # 14  is:  tensor(61.6008)
# 	 * Accuracy of candidate # 15  is:  tensor(49.6072)
# 	 * Accuracy of candidate # 16  is:  tensor(51.8972)
# 	 * Accuracy of candidate # 17  is:  tensor(40.8991)
# 	 * Accuracy of candidate # 18  is:  tensor(49.2270)
# 	 * Accuracy of candidate # 19  is:  tensor(51.2081)
# 	 * Accuracy of candidate # 20  is:  tensor(40.6920)
#
# 	Best Point Performs: 71.13964080810547
# Optimization iteration:

#
# 	Best Point Performs: 71.13964080810547
# Optimization iteration: 53
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(44.6992)
# 	 * Accuracy of candidate # 2  is:  tensor(42.7058)
# 	 * Accuracy of candidate # 3  is:  tensor(43.6938)
# 	 * Accuracy of candidate # 4  is:  tensor(49.9665)
# 	 * Accuracy of candidate # 5  is:  tensor(46.8249)
# 	 * Accuracy of candidate # 6  is:  tensor(40.9551)
# 	 * Accuracy of candidate # 7  is:  tensor(47.3921)
# 	 * Accuracy of candidate # 8  is:  tensor(50.1714)
# 	 * Accuracy of candidate # 9  is:  tensor(47.4645)
# 	 * Accuracy of candidate # 10  is:  tensor(46.2716)
# 	 * Accuracy of candidate # 11  is:  tensor(43.7154)
# 	 * Accuracy of candidate # 12  is:  tensor(43.8216)
# 	 * Accuracy of candidate # 13  is:  tensor(50.0718)
# 	 * Accuracy of candidate # 14  is:  tensor(47.4555)
# 	 * Accuracy of candidate # 15  is:  tensor(55.7207)
# 	 * Accuracy of candidate # 16  is:  tensor(54.8757)
# 	 * Accuracy of candidate # 17  is:  tensor(40.8339)
# 	 * Accuracy of candidate # 18  is:  tensor(53.5363)
# 	 * Accuracy of candidate # 19  is:  tensor(52.9811)
# 	 * Accuracy of candidate # 20  is:  tensor(45.6205)
#
# 	Best Point Performs: 71.13964080810547
# Optimization iteration: 54
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(57.7739)
# 	 * Accuracy of candidate # 2  is:  tensor(44.9214)
# 	 * Accuracy of candidate # 3  is:  tensor(45.7379)
# 	 * Accuracy of candidate # 4  is:  tensor(48.5470)
# 	 * Accuracy of candidate # 5  is:  tensor(57.6917)
# 	 * Accuracy of candidate # 6  is:  tensor(47.2128)
# 	 * Accuracy of candidate # 7  is:  tensor(45.3082)
# 	 * Accuracy of candidate # 8  is:  tensor(49.0628)
# 	 * Accuracy of candidate # 9  is:  tensor(66.3473)
# 	 * Accuracy of candidate # 10  is:  tensor(48.4457)
# 	 * Accuracy of candidate # 11  is:  tensor(54.3152)
# 	 * Accuracy of candidate # 12  is:  tensor(50.9970)
# 	 * Accuracy of candidate # 13  is:  tensor(47.4943)
# 	 * Accuracy of candidate # 14  is:  tensor(51.0424)
# 	 * Accuracy of candidate # 15  is:  tensor(50.7134)
# 	 * Accuracy of candidate # 16  is:  tensor(48.1389)
# 	 * Accuracy of candidate # 17  is:  tensor(45.2422)
# 	 * Accuracy of candidate # 18  is:  tensor(49.5352)
# 	 * Accuracy of candidate # 19  is:  tensor(44.6904)
# 	 * Accuracy of candidate # 20  is:  tensor(50.3926)
#
# 	Best Point Performs: 71.13964080810547
# Optimization iteration: 55
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(43.3600)
# 	 * Accuracy of candidate # 2  is:  tensor(46.7801)
# 	 * Accuracy of candidate # 3  is:  tensor(52.2171)
# 	 * Accuracy of candidate # 4  is:  tensor(49.5879)
# 	 * Accuracy of candidate # 5  is:  tensor(52.1290)
# 	 * Accuracy of candidate # 6  is:  tensor(44.3098)
# 	 * Accuracy of candidate # 7  is:  tensor(43.0555)
# 	 * Accuracy of candidate # 8  is:  tensor(49.9384)
# 	 * Accuracy of candidate # 9  is:  tensor(46.2538)
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(40.4787)
# 	 * Accuracy of candidate # 2  is:  tensor(53.8954)
# 	 * Accuracy of candidate # 3  is:  tensor(48.6798)
# 	 * Accuracy of candidate # 4  is:  tensor(43.2169)
# 	 * Accuracy of candidate # 5  is:  tensor(46.0603)
# 	 * Accuracy of candidate # 6  is:  tensor(53.8268)
# 	 * Accuracy of candidate # 7  is:  tensor(45.9433)
# 	 * Accuracy of candidate # 8  is:  tensor(49.3664)
# 	 * Accuracy of candidate # 9  is:  tensor(54.1983)
# 	 * Accuracy of candidate # 10  is:  tensor(43.6817)
# 	 * Accuracy of candidate # 11  is:  tensor(47.1222)
# 	 * Accuracy of candidate # 12  is:  tensor(49.6495)
# 	 * Accuracy of candidate # 13  is:  tensor(48.0474)
# 	 * Accuracy of candidate # 14  is:  tensor(49.3345)
# 	 * Accuracy of candidate # 15  is:  tensor(49.3345)
# 	 * Accuracy of candidate # 16  is:  tensor(46.6326)
# 	 * Accuracy of candidate # 17  is:  tensor(51.1862)
# 	 * Accuracy of candidate # 18  is:  tensor(42.6596)
# 	 * Accuracy of candidate # 19  is:  tensor(43.8951)
# 	 * Accuracy of candidate # 20  is:  tensor(45.5043)
#
# 	Best Point Performs: 71.13964080810547
# Optimization iteration: 59
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(45.6935)
# 	 * Accuracy of candidate # 2  is:  tensor(55.9394)
# 	 * Accuracy of candidate # 3  is:  tensor(46.5050)
# 	 * Accuracy of candidate # 4  is:  tensor(50.7368)
# 	 * Accuracy of candidate # 5  is:  tensor(54.9601)
# 	 * Accuracy of candidate # 6  is:  tensor(44.4457)
# 	 * Accuracy of candidate # 7  is:  tensor(47.1171)
# 	 * Accuracy of candidate # 8  is:  tensor(43.7019)
# 	 * Accuracy of candidate # 9  is:  tensor(49.4277)
# 	 * Accuracy of candidate # 10  is:  tensor(48.6216)
# 	 * Accuracy of candidate # 11  is:  tensor(43.2193)
# 	 * Accuracy of candidate # 12  is:  tensor(48.1615)
# 	 * Accuracy of candidate # 13  is:  tensor(44.8984)
# 	 * Accuracy of candidate # 14  is:  tensor(50.6895)
# 	 * Accuracy of candidate # 15  is:  tensor(47.9211)
# 	 * Accuracy of candidate # 16  is:  tensor(51.0179)
# 	 * Accuracy of candidate # 17  is:  tensor(45.9489)
# 	 * Accuracy of candidate # 18  is:  tensor(42.6503)
# 	 * Accuracy of candidate # 19  is:  tensor(48.8061)
# 	 * Accuracy of candidate # 20  is:  tensor(37.1142)
#
# 	Best Point Performs: 71.13964080810547
# Optimization iteration: 60
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(47.5569)
# 	 * Accuracy of candidate # 2  is:  tensor(44.9967)
# 	 * Accuracy of candidate # 3  is:

# %%
import torch
columns = [0, 1]
X = torch.tensor([[0.5] * 15 * 2, [6.1, 10] * 15])
values = X[..., columns]

# %%
X
# Out:
# tensor([[ 0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000,
#           0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000,
#           0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000,
#           0.5000,  0.5000,  0.5000,  0.5000,  0.5000,  0.5000],
#         [ 6.1000, 10.0000,  6.1000, 10.0000,  6.1000, 10.0000,  6.1000, 10.0000,
#           6.1000, 10.0000,  6.1000, 10.0000,  6.1000, 10.0000,  6.1000, 10.0000,
#           6.1000, 10.0000,  6.1000, 10.0000,  6.1000, 10.0000,  6.1000, 10.0000,
#           6.1000, 10.0000,  6.1000, 10.0000,  6.1000, 10.0000]])

# %%
values
# Out:
# tensor([[ 0.5000,  0.5000],
#         [ 6.1000, 10.0000]])
