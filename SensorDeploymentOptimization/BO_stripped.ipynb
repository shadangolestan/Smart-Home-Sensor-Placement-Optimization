# %%
import SensorOptimizers.BayesianOptimization as bo
import numpy as np
import pickle

acquisition_function = 'kg'
acq_optimizer_type = 'auto'
ROS = True
epsilon = 1
error = 0.25
multi_objective = False
LSsensorsNum = 7
ISsensorsNum = 0
initial_state = 'random'

sensor_types = {
    'model_motion_sensor': True,
    'model_beacon_sensor': False,
    'model_pressure_sensor': False,
    'model_accelerometer': False,
    'model_electricity_sensor': False
}

maxSensorNum = int(np.min([(8 / epsilon) * (8 / epsilon), LSsensorsNum]))

print('----- Running BO with: \n \t - epsilon: ', epsilon, 
      '\n \t - LS sensors #:', LSsensorsNum, 
      '\n \t - IS sensors #:', ISsensorsNum, 
      ' \n \t - initial state: ', initial_state)

for i in range(0, 3):
    history = bo.run(iteration = 1000, 
                     epsilon = epsilon, 
                     error = error,
                     ROS = True, 
                     multi_objective = multi_objective, 
                     LSmaxSensorNum = maxSensorNum,
                     ISmaxSensorNum = ISsensorsNum, 
                     initial_state = initial_state,
                     input_sensor_types = sensor_types,
                     acquisition_function = acquisition_function,
                     acq_optimizer_type = acq_optimizer_type)

    with open('Results_BO/history(IS' + str(ISsensorsNum) + ')_' + str(i), 'wb') as handle:
        pickle.dump(history, handle, protocol=pickle.HIGHEST_PROTOCOL)
            
    print(history)
# Out:
# ----- Running BO with:
#  	 - epsilon:  1
#  	 - LS sensors #: 7
#  	 - IS sensors #: 0
#  	 - initial state:  random
# 8.0
# 8.0
# [INFO] [2022-06-27 16:39:30,400] [Advisor] === [BO auto selection] === acq_optimizer_type: local_random.
# **************************************************
# self.acq_type  kg
# acq_optimizer_type  local_random
# self.num_objs  1
# self.surrogate_model  None
# self.num_constraints  0
# **************************************************
# [Build Surrogate] Use probabilistic random forest based on scikit-learn. For better performance, please install pyrfr: https://open-box.readthedocs.io/en/latest/installation/install_pyrfr.html
#   0%|                                                                                          | 0/1000 [00:04<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/q_/0btssn3s65l5hn0dytlnynmw0000gn/T/ipykernel_93444/4146969058.py in <module>
#      29
#      30 for i in range(0, 3):
# ---> 31     history = bo.run(iteration = 1000,
#      32                      epsilon = epsilon,
#      33                      error = error,
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/SensorOptimizers/BayesianOptimization.py in run(surrogate_type, acq_optimizer_type, acquisition_function, task_id, run_on_colab, iteration, epsilon, error, LSmaxSensorNum, ISmaxSensorNum, radius, print_epochs, height, width, ROS, multi_objective, initial_state, input_sensor_types)
#     740             error = CONSTANTS['error']
#     741         )
# --> 742         history = opt.run()
#     743
#     744
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/openbox/optimizer/generic_smbo.py in run(self)
#     215                 break
#     216             start_time = time.time()
# --> 217             self.iterate(budget_left=self.budget_left)
#     218             runtime = time.time() - start_time
#     219             self.budget_left -= runtime
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/openbox/optimizer/generic_smbo.py in iterate(self, budget_left)
#     234                 # evaluate configuration on objective_function within time_limit_per_trial
#     235                 args, kwargs = (config,), dict()
# --> 236                 timeout_status, _result = time_limit(self.objective_function,
#     237                                                      _time_limit_per_trial,
#     238                                                      args=args, kwargs=kwargs)
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/openbox/utils/limit.py in time_limit(func, time, *args, **kwargs)
#      82
#      83     if _platform == 'OSX' and sys.version_info >= (3, 8):
# ---> 84         return no_time_limit_func(func, time, *args, **kwargs)
#      85
#      86     parent_conn, child_conn = Pipe(False)
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/openbox/utils/limit.py in no_time_limit_func(objective_function, time, *args, **kwargs)
#      68
#      69 def no_time_limit_func(objective_function, time, *args, **kwargs):
# ---> 70     ret = objective_function(*args, **kwargs)
#      71     return Returns(timeout_status=False, results=ret)
#      72
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/SensorOptimizers/BayesianOptimization.py in function_to_be_optimized(config)
#     563     # print(sensorTypes)
#     564
# --> 565     return 100 - black_box_function(data,
#     566                                     simulateMotionSensors = sensor_types['model_motion_sensor'],
#     567                                     simulateEstimotes = sensor_types['model_beacon_sensor'],
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/SensorOptimizers/BayesianOptimization.py in black_box_function(sample, simulateMotionSensors, simulateEstimotes, simulateIS, Plotting)
#     488
#     489     for agentTrace in BOV.agentTraces:
# --> 490         df_ = sim_sis.RunSimulator(BOV.space,
#     491                                    BOV.rooms,
#     492                                    agentTrace,
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/SIM_SIS_Libraries/SIM_SIS_Simulator.py in RunSimulator(space, Rooms, agentTrace, sensorsConfiguration, simulateMotionSensorsflag, simulateEstimotesflag, simulateIS, plottingflag, Data_path)
#     530             fig, ax = plt.subplots(figsize = (8.5, 8.5))
#     531
# --> 532         RunSimulation(FDN, simulateMotionSensors, simulateEstimotes, simulateISSensors)
#     533
#     534     CreateUltimateDataset(UDN, Epoch)
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/SIM_SIS_Libraries/SIM_SIS_Simulator.py in RunSimulation(FDN, simulateMotionSensors, simulateEstimotes, simulateISSensors)
#     415         timetoadd = df_.time[i]
#     416
# --> 417         SimulateSensorReadings(simulateMotionSensors, simulateEstimotes, simulateISSensors, timetoadd, i, agent1Loc, action,  None)
#     418
#     419 def CreateUltimateDataset(UDN, epoch):
#
# ~/Library/CloudStorage/GoogleDrive-golestan@ualberta.ca/My Drive/PhD/Thesis/GreyBox Optimization Project/Codes/Smart-Home-Sensor-Placement-Optimization/SensorDeploymentOptimization/SIM_SIS_Libraries/SIM_SIS_Simulator.py in SimulateSensorReadings(simulateMotionSensors, simulateEstimotes, simulateISSensors, t, i, agent1Loc, action, agent2Loc)
#     303                 pp = ax.plot(float(sensor.x) / 100, float(sensor.y) / 100 , marker='.', color='k', lw=5)
#     304
# --> 305             circ = Circle((float(float(sensor.x) / 100), float(float(sensor.y) / 100)), float(float(sensor.sensing_area) / 100))
#     306
#     307             if (circ.contains_point([agent1Loc[0], agent1Loc[1]]) and (RecContains(agent1Loc[0], agent1Loc[1], sensor.room))):
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in __init__(self, xy, radius, **kwargs)
#    1576         %(Patch_kwdoc)s
#    1577         """
# -> 1578         super().__init__(xy, radius * 2, radius * 2, **kwargs)
#    1579         self.radius = radius
#    1580
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#    1450         %(Patch_kwdoc)s
#    1451         """
# -> 1452         super().__init__(**kwargs)
#    1453
#    1454         self._center = xy
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      82             antialiased = mpl.rcParams['patch.antialiased']
#      83
# ---> 84         self._hatch_color = colors.to_rgba(mpl.rcParams['hatch.color'])
#      85         self._fill = True  # needed for set_facecolor call
#      86         if color is not None:
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     194     """
#     195     # Special-case nth color syntax because it should not be cached.
# --> 196     if _is_nth_color(c):
#     197         from matplotlib import rcParams
#     198         prop_cycler = rcParams['axes.prop_cycle']
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/colors.py in _is_nth_color(c)
#     132 def _is_nth_color(c):
#     133     """Return whether *c* can be interpreted as an item in the color cycle."""
# --> 134     return isinstance(c, str) and re.match(r"\AC[0-9]+\Z", c)
#     135
#     136
#
# /opt/anaconda3/lib/python3.9/re.py in match(pattern, string, flags)
#     189     """Try to apply the pattern at the start of the string, returning
#     190     a Match object, or None if no match was found."""
# --> 191     return _compile(pattern, flags).match(string)
#     192
#     193 def fullmatch(pattern, string, flags=0):
#
# /opt/anaconda3/lib/python3.9/re.py in _compile(pattern, flags)
#     292         flags = flags.value
#     293     try:
# --> 294         return _cache[type(pattern), pattern, flags]
#     295     except KeyError:
#     296         pass
#
# KeyboardInterrupt:
