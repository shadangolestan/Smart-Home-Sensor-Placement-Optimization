# %%
# !pip3 install ax-platform
# !pip3 install botorch
# Out:
# Requirement already satisfied: ax-platform in /usr/local/lib/python3.9/site-packages (0.2.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from ax-platform) (2.11.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from ax-platform) (0.23.2)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.9/site-packages (from ax-platform) (2.13.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: botorch==0.5.1 in /usr/local/lib/python3.9/site-packages (from ax-platform) (0.5.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/site-packages (from ax-platform) (4.14.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.1.4)
# Requirement already satisfied: gpytorch>=1.5.1 in /usr/local/lib/python3.9/site-packages (from botorch==0.5.1->ax-platform) (1.5.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch==0.5.1->ax-platform) (1.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from ax-platform) (0.23.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch==0.5.1->ax-platform) (1.10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.9/site-packages (from jinja2->ax-platform) (1.1.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (1.19.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (2020.4)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.9/site-packages (from plotly->ax-platform) (1.3.3)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages (from plotly->ax-platform) (1.15.0)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages (from plotly->ax-platform) (1.15.0)
# Requirement already satisfied: six in /usr/local/Cellar/protobuf/3.14.0/libexec/lib/python3.9/site-packages (from plotly->ax-platform) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->ax-platform) (2.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from ax-platform) (1.5.4)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (1.19.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from scikit-learn->ax-platform) (0.17.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.9/site-packages (from pandas->ax-platform) (1.19.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from torch>=1.8.1->botorch==0.5.1->ax-platform) (3.10.0.2)
# Requirement already satisfied: botorch in /usr/local/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: gpytorch>=1.5.1 in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.1)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch) (1.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from gpytorch>=1.5.1->botorch) (0.23.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.9/site-packages (from botorch) (1.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (0.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from botorch) (1.5.4)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (1.19.4)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.9/site-packages (from scikit-learn->gpytorch>=1.5.1->botorch) (1.19.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/site-packages (from torch>=1.8.1->botorch) (3.10.0.2)

# %%
class Data:
    def __init__(self, sensorPositions, space, epsilon):
        self.radius = 1
        self.placeHolders = sensorPositions
        self.epsilon = epsilon
        self.space = space
        # self.SensorPlaceHolderSetup()
        
    def frange(self, start, stop, step):
        steps = []
        while start <= stop:
            steps.append(start)
            start +=step
            
        return steps

    def GetSensorConfiguration(self):
        from collections import Counter
        sensorLocations, sensorTypes = self.GetSensorLocations()

        summaryDict = Counter(sensorTypes)

        # TODO: DIFFERENT SENSOR TYPE DEFINITIONS SHOULD BE ADDED HERE:
        configurationSummary = []
        for key in summaryDict:
            if (key == 1):
                configurationSummary.append(['motion sensors', summaryDict[key]])

            elif (key == 2):
                configurationSummary.append(['beacon sensors', summaryDict[key]])

        configurationDetails = []
        for index, loc in enumerate(sensorLocations):
            if (sensorTypes[index] == 1):
                configurationDetails.append(tuple([loc, 'kitchen', 'motion sensors']))

            elif (sensorTypes[index] == 2):
                configurationDetails.append(tuple([loc, 'kitchen', 'beacon sensors']))

        return [[configurationSummary, [tuple(configurationDetails)]], self.radius]


    def GetSensorLocations(self):
        sensorLocations = []
        sensorTypes = []
        for index, sensorIndicator in enumerate(self.placeHolders):
            sensorLocations.append(self.placeHolders[index])

            # TODO: DIFFERENT SENSOR TYPE DEFINITIONS SHOULD BE ADDED HERE:
            sensorTypes.append(1)


        return sensorLocations, sensorTypes


class BOVariables:
    def __init__(self, Data_path, epsilon, initSensorNum, maxSensorNum, radius, sampleSize):
        self.epsilon = epsilon
        self.Data_path = Data_path
        self.initSensorNum = initSensorNum
        self.maxSensorNum = maxSensorNum
        self.radius = radius
        self.sensor_distribution, self.types, self.space, self.rooms, self.agentTraces = self.ModelsInitializations()

    def ModelsInitializations(self):
        #----- Space and agent models -----: 
        simworldname = self.Data_path + '/Configuration Files/simulationWorld2.xml'
        agentTraces = []
        directory = os.fsencode(self.Data_path + 'Agent Trace Files2/')
            
        for file in os.listdir(directory):
            filename = os.fsdecode(file)
            if filename.endswith(".csv"): 
                agentTraces.append(self.Data_path + 'Agent Trace Files2/' + filename)

        # Parsing the space model: 
        space, rooms = pf.ParseWorld(simworldname)

        xs = []
        for i in space:
          for j in i:
            xs.append(j)
        A = list(set(xs))
        A.sort()
        space = [A[-1], A[-2]]

        # User parameters 
        types, sensor_distribution = pf.GetUsersParameters()

        roomsList = []
        for room in sensor_distribution:
            roomsList.append(room)
              
        return sensor_distribution, types, space, rooms, agentTraces


def frange(start, stop, step):
    steps = []
    while start <= stop:
        steps.append(start)
        start +=step
        
    return steps

def MakeSensorCombinations(start, end, epsilon, sensorType, room):
    a1, b1 = makeBoundaries(epsilon, start[0], end[0])
    a2, b2 = makeBoundaries(epsilon, start[1], end[1])    
    Xs = frange(a1, b1, epsilon)
    Ys = frange(a2, b2, epsilon)
    
    points = list(itertools.product(list(itertools.product(Xs, Ys)), [room], [sensorType[0]])) 
    C = itertools.combinations(points, distribution[room][types.index(sensorType)])

    return C

def PreProcessor(df):
    df['motion sensors'] = df['motion sensors'].apply(lambda s: list(map(int, s)))
    try:
      df['beacon sensors'] = df['beacon sensors'].apply(lambda s: list(map(int, s)))
    except:
      pass

    sensors = set([])

    previous_M = None
    previous_B = None
    output_file = []

    for index, row in df.iterrows():
      T = row['time']
      M = row['motion sensors']
      try:
        B = row['beacon sensors']
      except:
        pass

      Activity = row['activity']
      Activity = Activity.replace(' ', '_')
      MotionSensor_Names = []
      sensorNames = []
      MotionSensor_Message = []
      BeaconSensor_Names = []
      BeaconSensor_Message = []
      

      # time = convertTime(T)
      time = "2020-06-16 " + T + ".00"

      # Motion Sensor
      for i in range(len(M)):
        sensorNames.append(Name(i, 'M'))
        if M[i] == 1:
          if (previous_M != None):
            if (previous_M[i] == 0):
              MotionSensor_Names.append(Name(i,'M'))
              MotionSensor_Message.append('ON')

          else:
            MotionSensor_Names.append(Name(i,'M'))
            MotionSensor_Message.append('ON')

        if previous_M != None:
          if M[i] == 0 and previous_M[i] == 1:
            MotionSensor_Names.append(Name(i,'M'))
            MotionSensor_Message.append('OFF')

      previous_M = M
      # Beacon Sensor

      try:
        for i in range(len(B)):
          sensorNames.append(Name(i, 'B'))
          if B[i] == 1:
            BeaconSensor_Names.append(Name(i,'B'))
            BeaconSensor_Message.append('ON')
          if previous_B != None:
            if B[i] == 0 and previous_B[i] == 1: 
              BeaconSensor_Names.append(Name(i,'B'))
              BeaconSensor_Message.append('OFF')
        previous_B = B

      except:
        pass

      for m in range(len(MotionSensor_Names)):
        output_file.append(time +' '+ MotionSensor_Names[m] + ' ' + MotionSensor_Names[m] + ' ' + MotionSensor_Message[m] + ' ' + Activity)
        
      for s in sensorNames:
          sensors.add(s)

    return output_file, list(sensors)

#returns the name of the sensor
def Name(number, typeSensor):
    if number < 10:
      return typeSensor + str(0) + str(number)
    else:
      return typeSensor + str(number)

#converts epoch time to human readable
def convertTime(posix_timestamp):
    tz = pytz.timezone('MST')
    dt = datetime.fromtimestamp(posix_timestamp, tz)
    time = dt.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
    return time

def MakeDataBoundaries(height = 10.5, width = 6.6, MaxSensors = 15):
    from collections import defaultdict, OrderedDict

    d = dict()

    for idx in range(MaxSensors):
            d['x' + str(idx)] = (0.5, width - 0.5)
            d['y' + str(idx)] = (0.5, height - 0.5)

    return d

def black_box_function(sample, simulateMotionSensors = True, simulateEstimotes = False, Plotting = False):       
    files = []

    if (runningOnGoogleColab == True):
        sys.path.append('gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/')
        Data_path = 'gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/'
        
    else:
        sys.path.append('../../Codes/Sensor Simulator/')
        Data_path = '../../Codes/Sensor Simulator/'

    all_sensors = set([])

    for agentTrace in BOV.agentTraces:
        df_ = sim_sis.RunSimulator(BOV.space, BOV.rooms, agentTrace, sample.GetSensorConfiguration(), simulateMotionSensors, simulateEstimotes, Plotting, BOV.Data_path)
        dataFile, sensors = PreProcessor(df_)
        all_sensors.update(sensors)
        files.append(dataFile)
        
    
    if (runningOnGoogleColab == True):
        sys.path.append('gdrive/My Drive/PhD/Thesis/Ideas/Codes/CASAS/AL-Smarthome')

    else:
        sys.path.append('../../Codes/CASAS/AL-Smarthome')

    import al
    import imp
    imp.reload(al)
    all_sensors = list(all_sensors)

    accuracy = (al.leave_one_out(files, all_sensors)[0]) * 100

    if accuracy < 0:
        accuracy = 0

    return [accuracy]

def function_to_be_optimized(T):
    sensorPositions = []
    sensor_xy = []
    for i, item in enumerate(T):
            if i % 2 == 0:
                sensor_xy.append(item)

            else:
                sensor_xy.append(item)  
                sensorPositions.append(sensor_xy)
                sensor_xy = []

    data = Data(sensorPositions, BOV.space, CONSTANTS['epsilon'])
    return torch.Tensor(black_box_function(data))

def InitializeDataset(BOV, init_num = 5):
    train_x = []
    for i in range(init_num):
        Xs = frange(0, BOV.space[0], BOV.epsilon)
        Ys = frange(0, BOV.space[1], BOV.epsilon)
        grid = np.zeros(len(Xs) * len(Ys)).tolist()
        placeHolders = []


        for x in Xs:
            for y in Ys:
                placeHolders.append([x, y])

        i = 0
        while i < BOV.initSensorNum:
            cell = random.randrange(len(grid))
            if grid[cell] == 0:
                grid[cell] = 1
                i += 1

        sensorPositions = []
        sensorTypes = []
        for index, sensorIndicator in enumerate(grid):
            if (sensorIndicator > 0):
                # sensorPositions.append(torch.Tensor(placeHolders[index]))
                sensorPositions.append(placeHolders[index][0])
                sensorPositions.append(placeHolders[index][1])
                sensorTypes.append(torch.Tensor(sensorIndicator))


        sensorPositions = torch.Tensor(sensorPositions)


        # data = Data(sensorPositions, BOV.space, CONSTANTS['epsilon'])
        train_x.append(sensorPositions)

    train_x = torch.stack(train_x)

    train_y = []

    sensorPositions = []
    sensor_xy = []
    for T in train_x:

        for i, item in enumerate(T):
            if i % 2 == 0:
                sensor_xy.append(item)

            else:
                sensor_xy.append(item)  
                sensorPositions.append(sensor_xy)
                sensor_xy = []

        data = Data(sensorPositions, BOV.space, CONSTANTS['epsilon'])
        train_y.append(torch.Tensor(black_box_function(data)))

    train_y = torch.stack(train_y)
    best_observed_value = train_y.max()

    return train_x, train_y, best_observed_value
    

def frange(start, stop, step):
    steps = []
    while start <= stop:
        steps.append(start)
        start +=step
        
    return steps

def get_next_points(train_x, train_y, best_observed_value, bounds, n_points = 10):
    single_model = SingleTaskGP(train_x, train_y)
    mll = ExactMarginalLogLikelihood(single_model.likelihood, single_model)
    fit_gpytorch_model(mll)
    
    print('----- Calculating Next Candidates Point From the Posterior PDF ...', end = " ")
    MES = qMaxValueEntropy(
                           model = single_model,
                           best_f = best_observed_value,
                           candidate_set = train_x
                          )
    

    candidates, _ = optimize_acqf(
                                  acq_function = MES,
                                  bounds = bounds,
                                  q = n_points, # number or candidates to return
                                  num_restarts = CONSTANTS['restarts_number'],
                                  raw_samples = CONSTANTS['raw_samples'],
                                  # options = {"batch_limit": 5, "maxiter": 100}
                                  sequential = CONSTANTS['sequential']
                                 )
    print('[COMPLETED]')

    return candidates

# %%
CONSTANTS = {
    'iterations': 100,
    'initial_samples': 50,
    'restarts_number': 15,
    'raw_samples': 15,
    'candidates_num': 20,
    'sequential': True,
    'epsilon': 1,
    'radius': 1,
    'height': 10.5,
    'width': 6.6,
    'max_sensors': 15  
}

global runningOnGoogleColab
runningOnGoogleColab = False
    
if __name__ ==  '__main__':
    import sys

    if (runningOnGoogleColab == True):
        from google.colab import drive    
        drive.mount('/content/gdrive', force_remount=True)
        Data_path = 'gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/'
        sys.path.append('gdrive/My Drive/PhD/Thesis/Ideas/Codes/Sensor Simulator/')
        
    else:
        Data_path = '../../Codes/Sensor Simulator/'
        sys.path.append('../../Codes/Sensor Simulator/')

    # from ax import optimize, ChoiceParameter
    from scipy.stats import norm
    from numpy import argmax
    import SIM_SIS_Libraries.SensorsClass
    import SIM_SIS_Libraries.SIM_SIS_Simulator as sim_sis
    import SIM_SIS_Libraries.ParseFunctions as pf
    import itertools
    import numpy as np
    import pandas as pd
    import SIM_SIS_Libraries.PreDeploymentEvaluation as pde
    import copy
    from datetime import datetime
    import pytz
    import ast
    import os
    import random
    import plotly
    import torch

    from botorch.models import SingleTaskGP, ModelListGP
    from gpytorch.mlls.exact_marginal_log_likelihood import ExactMarginalLogLikelihood
    from botorch import fit_gpytorch_model
    from botorch.acquisition.max_value_entropy_search import qMaxValueEntropy
    from botorch.optim import optimize_acqf

    # epsilon = 1
    # radius = 1
    finalResults = []
    # height = 10.5
    # width = 6.6
    # MaxSensors = 15
    w = CONSTANTS['width'] - 0.5
    h = CONSTANTS['height'] - 0.5
    # n_runs = 100
    # init_num = 10

    dataBoundaries = MakeDataBoundaries(
                                        height = CONSTANTS['height'], 
                                        width = CONSTANTS['width'], 
                                        MaxSensors = CONSTANTS['max_sensors']
                                       )

    BOV =  BOVariables(
                       Data_path, 
                       CONSTANTS['epsilon'], 
                       CONSTANTS['max_sensors'], 
                       CONSTANTS['max_sensors'], 
                       CONSTANTS['radius'],
                       CONSTANTS['initial_samples']
                      )
    
    print('----- Initializing Dataset... ', end = " ")
    train_x, train_y, best_observed_value = InitializeDataset(
                                                              BOV, 
                                                              init_num = CONSTANTS['initial_samples']
                                                             )
    
    print('[COMPLETED]')
    
    bounds = torch.tensor([[0.5] * CONSTANTS['max_sensors'] * 2, [w, h] * CONSTANTS['max_sensors']])

    for i in range(CONSTANTS['iterations']):
        print(f"Optimization iteration: {i + 1}")
        new_candidates = get_next_points(
                                         train_x, 
                                         train_y, 
                                         best_observed_value, 
                                         bounds, 
                                         n_points = CONSTANTS['candidates_num']
                                        )
        
        for index, candidate in enumerate(new_candidates):
            print('\t * Accuracy of candidate #', index + 1, ' is: ', end = " ")
            new_result = function_to_be_optimized(candidate)
            train_x = torch.cat([train_x, candidate.unsqueeze(0)])
            train_y = torch.cat([train_y, torch.stack([new_result])])
            print(new_result[0])

        best_observed_value = train_y.max().item()
        print(f"\n\tBest Point Performs: {best_observed_value}")
# Out:
# ----- Initializing Dataset...  [COMPLETED]
# Optimization iteration: 1
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(57.3052)
# 	 * Accuracy of candidate # 2  is:  tensor(41.7607)
# 	 * Accuracy of candidate # 3  is:  tensor(58.5392)
# 	 * Accuracy of candidate # 4  is:  tensor(46.0002)
# 	 * Accuracy of candidate # 5  is:  tensor(56.3829)
# 	 * Accuracy of candidate # 6  is:  tensor(50.1141)
# 	 * Accuracy of candidate # 7  is:  tensor(53.5295)
# 	 * Accuracy of candidate # 8  is:  tensor(49.1129)
# 	 * Accuracy of candidate # 9  is:  tensor(48.8422)
# 	 * Accuracy of candidate # 10  is:  tensor(48.1795)
# 	 * Accuracy of candidate # 11  is:  tensor(47.9241)
# 	 * Accuracy of candidate # 12  is:  tensor(47.6004)
# 	 * Accuracy of candidate # 13  is:  tensor(45.8227)
# 	 * Accuracy of candidate # 14  is:  tensor(57.0674)
# 	 * Accuracy of candidate # 15  is:  tensor(53.4114)
# 	 * Accuracy of candidate # 16  is:  tensor(53.0528)
# 	 * Accuracy of candidate # 17  is:  tensor(42.4637)
# 	 * Accuracy of candidate # 18  is:  tensor(42.8109)
# 	 * Accuracy of candidate # 19  is:  tensor(46.4758)
# 	 * Accuracy of candidate # 20  is:  tensor(47.7279)
#
# 	Best Point Performs: 58.53923416137695
# Optimization iteration: 2
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(44.7834)
# 	 * Accuracy of candidate # 2  is:  tensor(54.0831)
# 	 * Accuracy of candidate # 3  is:  tensor(56.0341)
# 	 * Accuracy of candidate # 4  is:  tensor(44.8644)
# 	 * Accuracy of candidate # 5  is:  tensor(40.0183)
# 	 * Accuracy of candidate # 6  is:  tensor(50.6123)
# 	 * Accuracy of candidate # 7  is:  tensor(47.8679)
# 	 * Accuracy of candidate # 8  is:  tensor(42.5834)
# 	 * Accuracy of candidate # 9  is:  tensor(44.2137)
# 	 * Accuracy of candidate # 10  is:  tensor(46.5761)
# 	 * Accuracy of candidate # 11  is:  tensor(52.2721)
# 	 * Accuracy of candidate # 12  is:  tensor(49.4598)
# 	 * Accuracy of candidate # 13  is:  tensor(48.0007)
# 	 * Accuracy of candidate # 14  is:  tensor(43.2103)
# 	 * Accuracy of candidate # 15  is:  tensor(45.6735)
# 	 * Accuracy of candidate # 16  is:  tensor(43.6163)
# 	 * Accuracy of candidate # 17  is:  tensor(47.0385)
# 	 * Accuracy of candidate # 18  is:  tensor(42.7836)
# 	 * Accuracy of candidate # 19  is:  tensor(49.2344)
# 	 * Accuracy of candidate # 20  is:  tensor(43.4273)
#
# 	Best Point Performs: 58.53923416137695
# Optimization iteration: 3
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(41.9109)
# 	 * Accuracy of candidate # 2  is:  tensor(44.8608)
# 	 * Accuracy of candidate # 3  is:  tensor(48.5849)
# 	 * Accuracy of candidate # 4  is:  tensor(46.8842)
# 	 * Accuracy of candidate # 5  is:  tensor(44.4549)
# 	 * Accuracy of candidate # 6  is:  tensor(51.6340)
# 	 * Accuracy of candidate # 7  is:  tensor(45.4324)
# 	 * Accuracy of candidate # 8  is:  tensor(53.2780)
# 	 * Accuracy of candidate # 9  is:  tensor(40.0741)
# 	 * Accuracy of candidate # 10  is:  tensor(45.6951)
# 	 * Accuracy of candidate # 11  is:  tensor(45.7799)
# 	 * Accuracy of candidate # 12  is:  tensor(48.1898)
# 	 * Accuracy of candidate # 13  is:  tensor(42.3743)
# 	 * Accuracy of candidate # 14  is:  tensor(51.7163)
# 	 * Accuracy of candidate # 15  is:  tensor(48.5938)
# 	 * Accuracy of candidate # 16  is:  tensor(50.6976)
# 	 * Accuracy of candidate # 17  is:  tensor(43.8655)
# 	 * Accuracy of candidate # 18  is:  tensor(45.3789)
# 	 * Accuracy of candidate # 19  is:  tensor(41.3932)
# 	 * Accuracy of candidate # 20  is:  tensor(39.7911)
#
# 	Best Point Performs: 58.53923416137695
# Optimization iteration: 4
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(42.1953)
# 	 * Accuracy of candidate # 2  is:  tensor(51.4048)
# 	 * Accuracy of candidate # 3  is:  tensor(52.5462)
# 	 * Accuracy of candidate # 4  is:  tensor(49.7826)
# 	 * Accuracy of candidate # 5  is:  tensor(48.0923)
# 	 * Accuracy of candidate # 6  is:  tensor(52.8819)
# 	 * Accuracy of candidate # 7  is:  tensor(48.1461)
# 	 * Accuracy of candidate # 8  is:  tensor(44.7793)
# 	 * Accuracy of candidate # 9  is:  tensor(43.7378)
# 	 * Accuracy of candidate # 10  is:  tensor(46.9401)
# 	 * Accuracy of candidate # 11  is:  tensor(47.1911)
# 	 * Accuracy of candidate # 12  is:  tensor(42.2181)
# 	 * Accuracy of candidate # 13  is:  tensor(44.1082)
# 	 * Accuracy of candidate # 14  is:  tensor(56.5206)
# 	 * Accuracy of candidate # 15  is:  tensor(54.6442)
# 	 * Accuracy of candidate # 16  is:  tensor(57.1880)
# 	 * Accuracy of candidate # 17  is:  tensor(42.4639)
# 	 * Accuracy of candidate # 18  is:  tensor(49.1410)
# 	 * Accuracy of candidate # 19  is:  tensor(50.7175)
# 	 * Accuracy of candidate # 20  is:  tensor(44.0859)
#
# 	Best Point Performs: 58.53923416137695
# Optimization iteration: 5
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(52.3661)
# 	 * Accuracy of candidate # 2  is:  tensor(49.1547)
# 	 * Accuracy of candidate # 3  is:  tensor(48.4440)
# 	 * Accuracy of candidate # 4  is:  tensor(43.2445)
# 	 * Accuracy of candidate # 5  is:  tensor(43.4292)
# 	 * Accuracy of candidate # 6  is:  tensor(52.9799)
# 	 * Accuracy of candidate # 7  is:  tensor(46.7764)
# 	 * Accuracy of candidate # 8  is:  tensor(49.1826)
# 	 * Accuracy of candidate # 9  is:  tensor(49.6779)
# 	 * Accuracy of candidate # 10  is:  tensor(48.7533)
# 	 * Accuracy of candidate # 11  is:  tensor(58.0393)
# 	 * Accuracy of candidate # 12  is:  tensor(51.0577)
# 	 * Accuracy of candidate # 13  is:  tensor(51.0563)
# 	 * Accuracy of candidate # 14  is:  tensor(44.7608)
# 	 * Accuracy of candidate # 15  is:  tensor(39.7034)
# 	 * Accuracy of candidate # 16  is:  tensor(56.1907)
# 	 * Accuracy of candidate # 17  is:  tensor(49.2125)
# 	 * Accuracy of candidate # 18  is:  tensor(58.4594)
# 	 * Accuracy of candidate # 19  is:  tensor(48.7494)
# 	 * Accuracy of candidate # 20  is:  tensor(38.7620)
#
# 	Best Point Performs: 58.53923416137695
# Optimization iteration: 6
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(44.1785)
# 	 * Accuracy of candidate # 2  is:  tensor(49.6279)
# 	 * Accuracy of candidate # 3  is:  tensor(53.1044)
# 	 * Accuracy of candidate # 4  is:  tensor(49.8537)
# 	 * Accuracy of candidate # 5  is:  tensor(48.5418)
# 	 * Accuracy of candidate # 6  is:  tensor(52.2525)
# 	 * Accuracy of candidate # 7  is:  tensor(46.0792)
# 	 * Accuracy of candidate # 8  is:  tensor(48.1819)
# 	 * Accuracy of candidate # 9  is:  tensor(51.1946)
# 	 * Accuracy of candidate # 10  is:  tensor(50.4072)
# 	 * Accuracy of candidate # 11  is:  tensor(44.1794)
# 	 * Accuracy of candidate # 12  is:  tensor(51.4427)
# 	 * Accuracy of candidate # 13  is:  tensor(46.4260)
# 	 * Accuracy of candidate # 14  is:  tensor(48.6214)
# 	 * Accuracy of candidate # 15  is:  tensor(40.7841)
# 	 * Accuracy of candidate # 16  is:  tensor(46.6668)
# 	 * Accuracy of candidate # 17  is:  tensor(51.7809)
# 	 * Accuracy of candidate # 18  is:  tensor(42.8590)
# 	 * Accuracy of candidate # 19  is:  tensor(48.3231)
# 	 * Accuracy of candidate # 20  is:  tensor(48.0130)
#
# 	Best Point Performs: 58.53923416137695
# Optimization iteration: 7
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(43.4173)
# 	 * Accuracy of candidate # 2  is:  tensor(46.5217)
# 	 * Accuracy of candidate # 3  is:  tensor(55.0660)
# 	 * Accuracy of candidate # 4  is:  tensor(41.5894)
# 	 * Accuracy of candidate # 5  is:  tensor(53.5333)
# 	 * Accuracy of candidate # 6  is:  tensor(45.9884)
# 	 * Accuracy of candidate # 7  is:  tensor(50.8687)
# 	 * Accuracy of candidate # 8  is:  tensor(50.5463)
# 	 * Accuracy of candidate # 9  is:  tensor(47.7025)
# 	 * Accuracy of candidate # 10  is:  tensor(44.6486)
# 	 * Accuracy of candidate # 11  is:  tensor(58.3126)
# 	 * Accuracy of candidate # 12  is:  tensor(48.8442)
# 	 * Accuracy of candidate # 13  is:  tensor(47.1223)
# 	 * Accuracy of candidate # 14  is:  tensor(45.1586)
# 	 * Accuracy of candidate # 15  is:  tensor(44.1303)
# 	 * Accuracy of candidate # 16  is:  tensor(52.1263)
# 	 * Accuracy of candidate # 17  is:  tensor(47.6022)
# 	 * Accuracy of candidate # 18  is:  tensor(49.1511)
# 	 * Accuracy of candidate # 19  is:  tensor(51.2765)
# 	 * Accuracy of candidate # 20  is:  tensor(49.1234)
#
# 	Best Point Performs: 58.53923416137695
# Optimization iteration: 8
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(51.8175)
# 	 * Accuracy of candidate # 2  is:  tensor(53.6192)
# 	 * Accuracy of candidate # 3  is:  tensor(48.1907)
# 	 * Accuracy of candidate # 4  is:  tensor(50.6468)
# 	 * Accuracy of candidate # 5  is:  tensor(48.3893)
# 	 * Accuracy of candidate # 6  is:  tensor(54.1090)
# 	 * Accuracy of candidate # 7  is:  tensor(42.3195)
# 	 * Accuracy of candidate # 8  is:  tensor(55.5712)
# 	 * Accuracy of candidate # 9  is:  tensor(51.1578)
# 	 * Accuracy of candidate # 10  is:  tensor(51.7655)
# 	 * Accuracy of candidate # 11  is:  tensor(52.1203)
# 	 * Accuracy of candidate # 12  is:  tensor(45.9488)
# 	 * Accuracy of candidate # 13  is:  tensor(45.1452)
# 	 * Accuracy of candidate # 14  is:  tensor(45.1783)
# 	 * Accuracy of candidate # 15  is:  tensor(43.3307)
# 	 * Accuracy of candidate # 16  is:  tensor(41.0895)
# 	 * Accuracy of candidate # 17  is:  tensor(48.3797)
# 	 * Accuracy of candidate # 18  is:  tensor(57.4865)
# 	 * Accuracy of candidate # 19  is:  tensor(54.1324)
# 	 * Accuracy of candidate # 20  is:  tensor(53.3344)
#
# 	Best Point Performs: 58.53923416137695
# Optimization iteration: 9
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(46.1517)
# 	 * Accuracy of candidate # 2  is:  tensor(41.2258)
# 	 * Accuracy of candidate # 3  is:  tensor(48.9590)
# 	 * Accuracy of candidate # 4  is:  tensor(47.1154)
# 	 * Accuracy of candidate # 5  is:  tensor(45.6524)
# 	 * Accuracy of candidate # 6  is:  tensor(49.2279)
# 	 * Accuracy of candidate # 7  is:  tensor(48.3204)
# 	 * Accuracy of candidate # 8  is:  tensor(44.0262)
# 	 * Accuracy of candidate # 9  is:  tensor(46.4344)
# 	 * Accuracy of candidate # 10  is:  tensor(50.8194)
# 	 * Accuracy of candidate # 11  is:  tensor(43.4853)
# 	 * Accuracy of candidate # 12  is:  tensor(51.2500)
# 	 * Accuracy of candidate # 13  is:  tensor(58.3065)
# 	 * Accuracy of candidate # 14  is:  tensor(50.2447)
# 	 * Accuracy of candidate # 15  is:  tensor(45.0144)
# 	 * Accuracy of candidate # 16  is:  tensor(47.0629)
# 	 * Accuracy of candidate # 17  is:  tensor(53.4175)
# 	 * Accuracy of candidate # 18  is:  tensor(47.0106)
# 	 * Accuracy of candidate # 19  is:  tensor(45.7730)
# 	 * Accuracy of candidate # 20  is:  tensor(58.7244)
#
# 	Best Point Performs: 58.72439956665039
# Optimization iteration: 10
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(43.4939)
# 	 * Accuracy of candidate # 2  is:  tensor(50.6281)
# 	 * Accuracy of candidate # 3  is:  tensor(51.2712)
# 	 * Accuracy of candidate # 4  is:  tensor(50.1497)
# 	 * Accuracy of candidate # 5  is:  tensor(50.5203)
# 	 * Accuracy of candidate # 6  is:  tensor(46.6128)
# 	 * Accuracy of candidate # 7  is:  tensor(49.4695)
# 	 * Accuracy of candidate # 8  is:  tensor(50.6499)
# 	 * Accuracy of candidate # 9  is:  tensor(46.0093)
# 	 * Accuracy of candidate # 10  is:  tensor(50.1051)
# 	 * Accuracy of candidate # 11  is:  tensor(54.9938)
# 	 * Accuracy of candidate # 12  is:  tensor(46.0774)
# 	 * Accuracy of candidate # 13  is:  tensor(51.7280)
# 	 * Accuracy of candidate # 14  is:  tensor(41.1763)
# 	 * Accuracy of candidate # 15  is:  tensor(51.9926)
# 	 * Accuracy of candidate # 16  is:  tensor(47.8650)
# 	 * Accuracy of candidate # 17  is:  tensor(50.6209)
# 	 * Accuracy of candidate # 18  is:  tensor(47.7345)
# 	 * Accuracy of candidate # 19  is:  tensor(48.4583)
# 	 * Accuracy of candidate # 20  is:  tensor(54.2264)
#
# 	Best Point Performs: 58.72439956665039
# Optimization iteration: 11
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(50.5822)
# 	 * Accuracy of candidate # 2  is:  tensor(42.8078)
# 	 * Accuracy of candidate # 3  is:  tensor(48.2137)
# 	 * Accuracy of candidate # 4  is:  tensor(47.4669)
# 	 * Accuracy of candidate # 5  is:  tensor(53.2060)
# 	 * Accuracy of candidate # 6  is:  tensor(46.3351)
# 	 * Accuracy of candidate # 7  is:  tensor(50.8790)
# 	 * Accuracy of candidate # 8  is:  tensor(49.4946)
# 	 * Accuracy of candidate # 9  is:  tensor(46.4431)
# 	 * Accuracy of candidate # 10  is:  tensor(42.1631)
# 	 * Accuracy of candidate # 11  is:  tensor(57.4061)
# 	 * Accuracy of candidate # 12  is:  tensor(44.6801)
# 	 * Accuracy of candidate # 13  is:  tensor(46.3767)
# 	 * Accuracy of candidate # 14  is:  tensor(45.0717)
# 	 * Accuracy of candidate # 15  is:  tensor(43.6003)
# 	 * Accuracy of candidate # 16  is:  tensor(46.3782)
# 	 * Accuracy of candidate # 17  is:  tensor(50.9524)
# 	 * Accuracy of candidate # 18  is:  tensor(47.0678)
# 	 * Accuracy of candidate # 19  is:  tensor(52.0707)
# 	 * Accuracy of candidate # 20  is:  tensor(48.4967)
#
# 	Best Point Performs: 58.72439956665039
# Optimization iteration: 12
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(49.9971)
# 	 * Accuracy of candidate # 2  is:  tensor(53.0644)
# 	 * Accuracy of candidate # 3  is:  tensor(41.3235)
# 	 * Accuracy of candidate # 4  is:  tensor(42.1830)
# 	 * Accuracy of candidate # 5  is:  tensor(50.7931)
# 	 * Accuracy of candidate # 6  is:  tensor(50.4543)
# 	 * Accuracy of candidate # 7  is:  tensor(55.4944)
# 	 * Accuracy of candidate # 8  is:  tensor(48.5243)
# 	 * Accuracy of candidate # 9  is:  tensor(44.1769)
# 	 * Accuracy of candidate # 10  is:  tensor(54.5828)
# 	 * Accuracy of candidate # 11  is:  tensor(48.3179)
# 	 * Accuracy of candidate # 12  is:  tensor(52.1584)
# 	 * Accuracy of candidate # 13  is:  tensor(47.6181)
# 	 * Accuracy of candidate # 14  is:  tensor(43.4305)
# 	 * Accuracy of candidate # 15  is:  tensor(47.7711)
# 	 * Accuracy of candidate # 16  is:  tensor(46.7631)
# 	 * Accuracy of candidate # 17  is:  tensor(54.5779)
# 	 * Accuracy of candidate # 18  is:  tensor(68.3357)
# 	 * Accuracy of candidate # 19  is:  tensor(57.9613)
# 	 * Accuracy of candidate # 20  is:  tensor(53.8389)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 13
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(40.3662)
# 	 * Accuracy of candidate # 2  is:  tensor(46.5883)
# 	 * Accuracy of candidate # 3  is:  tensor(50.8908)
# 	 * Accuracy of candidate # 4  is:  tensor(49.2129)
# 	 * Accuracy of candidate # 5  is:  tensor(51.4853)
# 	 * Accuracy of candidate # 6  is:  tensor(49.3359)
# 	 * Accuracy of candidate # 7  is:  tensor(57.5744)
# 	 * Accuracy of candidate # 8  is:  tensor(49.6031)
# 	 * Accuracy of candidate # 9  is:  tensor(43.7669)
# 	 * Accuracy of candidate # 10  is:  tensor(46.6348)
# 	 * Accuracy of candidate # 11  is:  tensor(41.8244)
# 	 * Accuracy of candidate # 12  is:  tensor(51.6043)
# 	 * Accuracy of candidate # 13  is:  tensor(44.3889)
# 	 * Accuracy of candidate # 14  is:  tensor(45.8671)
# 	 * Accuracy of candidate # 15  is:  tensor(46.4723)
# 	 * Accuracy of candidate # 16  is:  tensor(49.1233)
# 	 * Accuracy of candidate # 17  is:  tensor(46.6115)
# 	 * Accuracy of candidate # 18  is:  tensor(47.2809)
# 	 * Accuracy of candidate # 19  is:  tensor(49.5008)
# 	 * Accuracy of candidate # 20  is:  tensor(56.3357)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 14
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(55.9416)
# 	 * Accuracy of candidate # 2  is:  tensor(49.2752)
# 	 * Accuracy of candidate # 3  is:  tensor(49.9796)
# 	 * Accuracy of candidate # 4  is:  tensor(57.6548)
# 	 * Accuracy of candidate # 5  is:  tensor(59.9110)
# 	 * Accuracy of candidate # 6  is:  tensor(44.8598)
# 	 * Accuracy of candidate # 7  is:  tensor(43.8230)
# 	 * Accuracy of candidate # 8  is:  tensor(50.0300)
# 	 * Accuracy of candidate # 9  is:  tensor(54.2844)
# 	 * Accuracy of candidate # 10  is:  tensor(57.5904)
# 	 * Accuracy of candidate # 11  is:  tensor(54.1003)
# 	 * Accuracy of candidate # 12  is:  tensor(48.1027)
# 	 * Accuracy of candidate # 13  is:  tensor(47.8933)
# 	 * Accuracy of candidate # 14  is:  tensor(48.8930)
# 	 * Accuracy of candidate # 15  is:  tensor(48.0712)
# 	 * Accuracy of candidate # 16  is:  tensor(48.8813)
# 	 * Accuracy of candidate # 17  is:  tensor(50.0001)
# 	 * Accuracy of candidate # 18  is:  tensor(47.3970)
# 	 * Accuracy of candidate # 19  is:  tensor(49.6271)
# 	 * Accuracy of candidate # 20  is:  tensor(48.2194)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 15
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(49.3130)
# 	 * Accuracy of candidate # 2  is:  tensor(45.6361)
# 	 * Accuracy of candidate # 3  is:  tensor(54.8113)
# 	 * Accuracy of candidate # 4  is:  tensor(41.3591)
# 	 * Accuracy of candidate # 5  is:  tensor(55.2405)
# 	 * Accuracy of candidate # 6  is:  tensor(51.0072)
# 	 * Accuracy of candidate # 7  is:  tensor(42.8600)
# 	 * Accuracy of candidate # 8  is:  tensor(54.1853)
# 	 * Accuracy of candidate # 9  is:  tensor(44.5249)
# 	 * Accuracy of candidate # 10  is:  tensor(47.0105)
# 	 * Accuracy of candidate # 11  is:  tensor(48.2656)
# 	 * Accuracy of candidate # 12  is:  tensor(56.0588)
# 	 * Accuracy of candidate # 13  is:  tensor(49.1287)
# 	 * Accuracy of candidate # 14  is:  tensor(45.6510)
# 	 * Accuracy of candidate # 15  is:  tensor(41.2646)
# 	 * Accuracy of candidate # 16  is:  tensor(45.6708)
# 	 * Accuracy of candidate # 17  is:  tensor(47.8902)
# 	 * Accuracy of candidate # 18  is:  tensor(48.1218)
# 	 * Accuracy of candidate # 19  is:  tensor(54.0948)
# 	 * Accuracy of candidate # 20  is:  tensor(49.1597)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 16
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(41.6055)
# 	 * Accuracy of candidate # 2  is:  tensor(51.9377)
# 	 * Accuracy of candidate # 3  is:  tensor(56.9829)
# 	 * Accuracy of candidate # 4  is:  tensor(44.3288)
# 	 * Accuracy of candidate # 5  is:  tensor(47.2264)
# 	 * Accuracy of candidate # 6  is:  tensor(52.1110)
# 	 * Accuracy of candidate # 7  is:  tensor(52.5607)
# 	 * Accuracy of candidate # 8  is:  tensor(41.5882)
# 	 * Accuracy of candidate # 9  is:  tensor(38.5786)
# 	 * Accuracy of candidate # 10  is:  tensor(47.8772)
# 	 * Accuracy of candidate # 11  is:  tensor(47.0257)
# 	 * Accuracy of candidate # 12  is:  tensor(56.3658)
# 	 * Accuracy of candidate # 13  is:  tensor(46.7574)
# 	 * Accuracy of candidate # 14  is:  tensor(44.6910)
# 	 * Accuracy of candidate # 15  is:  tensor(49.8336)
# 	 * Accuracy of candidate # 16  is:  tensor(48.2028)
# 	 * Accuracy of candidate # 17  is:  tensor(57.2127)
# 	 * Accuracy of candidate # 18  is:  tensor(49.7815)
# 	 * Accuracy of candidate # 19  is:  tensor(48.8223)
# 	 * Accuracy of candidate # 20  is:  tensor(53.2554)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 17
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(45.7665)
# 	 * Accuracy of candidate # 2  is:  tensor(49.3414)
# 	 * Accuracy of candidate # 3  is:  tensor(44.9952)
# 	 * Accuracy of candidate # 4  is:  tensor(53.4954)
# 	 * Accuracy of candidate # 5  is:  tensor(40.8310)
# 	 * Accuracy of candidate # 6  is:  tensor(45.8882)
# 	 * Accuracy of candidate # 7  is:  tensor(52.3131)
# 	 * Accuracy of candidate # 8  is:  tensor(45.5207)
# 	 * Accuracy of candidate # 9  is:  tensor(57.5537)
# 	 * Accuracy of candidate # 10  is:  tensor(48.5055)
# 	 * Accuracy of candidate # 11  is:  tensor(46.8711)
# 	 * Accuracy of candidate # 12  is:  tensor(53.1882)
# 	 * Accuracy of candidate # 13  is:  tensor(46.3653)
# 	 * Accuracy of candidate # 14  is:  tensor(47.1058)
# 	 * Accuracy of candidate # 15  is:  tensor(48.2354)
# 	 * Accuracy of candidate # 16  is:  tensor(50.4275)
# 	 * Accuracy of candidate # 17  is:  tensor(54.1063)
# 	 * Accuracy of candidate # 18  is:  tensor(46.1101)
# 	 * Accuracy of candidate # 19  is:  tensor(47.2406)
# 	 * Accuracy of candidate # 20  is:  tensor(50.3344)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 18
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(43.2373)
# 	 * Accuracy of candidate # 2  is:  tensor(48.2102)
# 	 * Accuracy of candidate # 3  is:  tensor(49.7975)
# 	 * Accuracy of candidate # 4  is:  tensor(52.7389)
# 	 * Accuracy of candidate # 5  is:  tensor(47.8610)
# 	 * Accuracy of candidate # 6  is:  tensor(49.1422)
# 	 * Accuracy of candidate # 7  is:  tensor(43.3533)
# 	 * Accuracy of candidate # 8  is:  tensor(49.8818)
# 	 * Accuracy of candidate # 9  is:  tensor(47.4874)
# 	 * Accuracy of candidate # 10  is:  tensor(41.2388)
# 	 * Accuracy of candidate # 11  is:  tensor(50.6308)
# 	 * Accuracy of candidate # 12  is:  tensor(43.6073)
# 	 * Accuracy of candidate # 13  is:  tensor(49.7362)
# 	 * Accuracy of candidate # 14  is:  tensor(44.2758)
# 	 * Accuracy of candidate # 15  is:  tensor(56.4625)
# 	 * Accuracy of candidate # 16  is:  tensor(49.2096)
# 	 * Accuracy of candidate # 17  is:  tensor(46.2261)
# 	 * Accuracy of candidate # 18  is:  tensor(42.8140)
# 	 * Accuracy of candidate # 19  is:  tensor(46.5440)
# 	 * Accuracy of candidate # 20  is:  tensor(45.4154)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 19
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(46.4453)
# 	 * Accuracy of candidate # 2  is:  tensor(47.9699)
# 	 * Accuracy of candidate # 3  is:  tensor(45.3438)
# 	 * Accuracy of candidate # 4  is:  tensor(45.4277)
# 	 * Accuracy of candidate # 5  is:  tensor(45.7189)
# 	 * Accuracy of candidate # 6  is:  tensor(49.4259)
# 	 * Accuracy of candidate # 7  is:  tensor(52.4389)
# 	 * Accuracy of candidate # 8  is:  tensor(46.2936)
# 	 * Accuracy of candidate # 9  is:  tensor(47.7270)
# 	 * Accuracy of candidate # 10  is:  tensor(46.6218)
# 	 * Accuracy of candidate # 11  is:  tensor(45.4522)
# 	 * Accuracy of candidate # 12  is:  tensor(45.9481)
# 	 * Accuracy of candidate # 13  is:  tensor(52.9750)
# 	 * Accuracy of candidate # 14  is:  tensor(49.7745)
# 	 * Accuracy of candidate # 15  is:  tensor(48.6316)
# 	 * Accuracy of candidate # 16  is:  tensor(47.6202)
# 	 * Accuracy of candidate # 17  is:  tensor(41.9576)
# 	 * Accuracy of candidate # 18  is:  tensor(45.6486)
# 	 * Accuracy of candidate # 19  is:  tensor(54.0284)
# 	 * Accuracy of candidate # 20  is:  tensor(50.6289)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 20
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(59.9197)
# 	 * Accuracy of candidate # 2  is:  tensor(46.3172)
# 	 * Accuracy of candidate # 3  is:  tensor(46.3682)
# 	 * Accuracy of candidate # 4  is:  tensor(43.3734)
# 	 * Accuracy of candidate # 5  is:  tensor(47.1029)
# 	 * Accuracy of candidate # 6  is:  tensor(45.1978)
# 	 * Accuracy of candidate # 7  is:  tensor(47.8534)
# 	 * Accuracy of candidate # 8  is:  tensor(52.2131)
# 	 * Accuracy of candidate # 9  is:  tensor(52.6503)
# 	 * Accuracy of candidate # 10  is:  tensor(49.5393)
# 	 * Accuracy of candidate # 11  is:  tensor(44.9590)
# 	 * Accuracy of candidate # 12  is:  tensor(54.2191)
# 	 * Accuracy of candidate # 13  is:  tensor(51.2065)
# 	 * Accuracy of candidate # 14  is:  tensor(49.8954)
# 	 * Accuracy of candidate # 15  is:  tensor(45.8015)
# 	 * Accuracy of candidate # 16  is:  tensor(49.4411)
# 	 * Accuracy of candidate # 17  is:  tensor(46.9745)
# 	 * Accuracy of candidate # 18  is:  tensor(46.2733)
# 	 * Accuracy of candidate # 19  is:  tensor(49.7417)
# 	 * Accuracy of candidate # 20  is:  tensor(53.7780)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 21
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(46.7698)
# 	 * Accuracy of candidate # 2  is:  tensor(47.9629)
# 	 * Accuracy of candidate # 3  is:  tensor(45.6635)
# 	 * Accuracy of candidate # 4  is:  tensor(45.1888)
# 	 * Accuracy of candidate # 5  is:  tensor(45.2618)
# 	 * Accuracy of candidate # 6  is:  tensor(43.4015)
# 	 * Accuracy of candidate # 7  is:  tensor(46.2054)
# 	 * Accuracy of candidate # 8  is:  tensor(53.2973)
# 	 * Accuracy of candidate # 9  is:  tensor(48.9231)
# 	 * Accuracy of candidate # 10  is:  tensor(47.4482)
# 	 * Accuracy of candidate # 11  is:  tensor(51.4261)
# 	 * Accuracy of candidate # 12  is:  tensor(48.6736)
# 	 * Accuracy of candidate # 13  is:  tensor(43.8797)
# 	 * Accuracy of candidate # 14  is:  tensor(44.4623)
# 	 * Accuracy of candidate # 15  is:  tensor(49.6282)
# 	 * Accuracy of candidate # 16  is:  tensor(51.1284)
# 	 * Accuracy of candidate # 17  is:  tensor(52.7995)
# 	 * Accuracy of candidate # 18  is:  tensor(56.7750)
# 	 * Accuracy of candidate # 19  is:  tensor(58.8971)
# 	 * Accuracy of candidate # 20  is:  tensor(47.7180)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 22
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(47.8592)
# 	 * Accuracy of candidate # 2  is:  tensor(53.6635)
# 	 * Accuracy of candidate # 3  is:  tensor(59.0919)
# 	 * Accuracy of candidate # 4  is:  tensor(45.5753)
# 	 * Accuracy of candidate # 5  is:  tensor(43.3349)
# 	 * Accuracy of candidate # 6  is:  tensor(46.7387)
# 	 * Accuracy of candidate # 7  is:  tensor(57.4862)
# 	 * Accuracy of candidate # 8  is:  tensor(46.9481)
# 	 * Accuracy of candidate # 9  is:  tensor(55.9113)
# 	 * Accuracy of candidate # 10  is:  tensor(42.0864)
# 	 * Accuracy of candidate # 11  is:  tensor(43.6966)
# 	 * Accuracy of candidate # 12  is:  tensor(48.6381)
# 	 * Accuracy of candidate # 13  is:  tensor(48.6657)
# 	 * Accuracy of candidate # 14  is:  tensor(48.8214)
# 	 * Accuracy of candidate # 15  is:  tensor(54.2748)
# 	 * Accuracy of candidate # 16  is:  tensor(46.4987)
# 	 * Accuracy of candidate # 17  is:  tensor(47.7124)
# 	 * Accuracy of candidate # 18  is:  tensor(51.6159)
# 	 * Accuracy of candidate # 19  is:  tensor(41.4846)
# 	 * Accuracy of candidate # 20  is:  tensor(43.8538)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 23
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(52.2379)
# 	 * Accuracy of candidate # 2  is:  tensor(51.3235)
# 	 * Accuracy of candidate # 3  is:  tensor(55.5801)
# 	 * Accuracy of candidate # 4  is:  tensor(44.2494)
# 	 * Accuracy of candidate # 5  is:  tensor(62.2064)
# 	 * Accuracy of candidate # 6  is:  tensor(45.1963)
# 	 * Accuracy of candidate # 7  is:  tensor(59.1044)
# 	 * Accuracy of candidate # 8  is:  tensor(49.3686)
# 	 * Accuracy of candidate # 9  is:  tensor(53.4902)
# 	 * Accuracy of candidate # 10  is:  tensor(51.2871)
# 	 * Accuracy of candidate # 11  is:  tensor(47.3644)
# 	 * Accuracy of candidate # 12  is:  tensor(52.1708)
# 	 * Accuracy of candidate # 13  is:  tensor(56.6438)
# 	 * Accuracy of candidate # 14  is:  tensor(54.8736)
# 	 * Accuracy of candidate # 15  is:  tensor(40.6809)
# 	 * Accuracy of candidate # 16  is:  tensor(45.0735)
# 	 * Accuracy of candidate # 17  is:  tensor(58.3543)
# 	 * Accuracy of candidate # 18  is:  tensor(46.6456)
# 	 * Accuracy of candidate # 19  is:  tensor(45.2678)
# 	 * Accuracy of candidate # 20  is:  tensor(54.0226)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 24
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(52.4461)
# 	 * Accuracy of candidate # 2  is:  tensor(49.5968)
# 	 * Accuracy of candidate # 3  is:  tensor(60.1236)
# 	 * Accuracy of candidate # 4  is:  tensor(38.3810)
# 	 * Accuracy of candidate # 5  is:  tensor(45.9602)
# 	 * Accuracy of candidate # 6  is:  tensor(47.4858)
# 	 * Accuracy of candidate # 7  is:  tensor(52.8458)
# 	 * Accuracy of candidate # 8  is:  tensor(47.1027)
# 	 * Accuracy of candidate # 9  is:  tensor(47.4535)
# 	 * Accuracy of candidate # 10  is:  tensor(52.0884)
# 	 * Accuracy of candidate # 11  is:  tensor(44.2709)
# 	 * Accuracy of candidate # 12  is:  tensor(49.9227)
# 	 * Accuracy of candidate # 13  is:  tensor(40.9230)
# 	 * Accuracy of candidate # 14  is:  tensor(56.2419)
# 	 * Accuracy of candidate # 15  is:  tensor(52.0009)
# 	 * Accuracy of candidate # 16  is:  tensor(46.6344)
# 	 * Accuracy of candidate # 17  is:  tensor(47.0064)
# 	 * Accuracy of candidate # 18  is:  tensor(49.9246)
# 	 * Accuracy of candidate # 19  is:  tensor(45.9642)
# 	 * Accuracy of candidate # 20  is:  tensor(43.2573)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 25
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(49.2860)
# 	 * Accuracy of candidate # 2  is:  tensor(48.9611)
# 	 * Accuracy of candidate # 3  is:  tensor(49.9362)
# 	 * Accuracy of candidate # 4  is:  tensor(57.3240)
# 	 * Accuracy of candidate # 5  is:  tensor(39.1612)
# 	 * Accuracy of candidate # 6  is:  tensor(46.8117)
# 	 * Accuracy of candidate # 7  is:  tensor(47.4103)
# 	 * Accuracy of candidate # 8  is:  tensor(45.2302)
# 	 * Accuracy of candidate # 9  is:  tensor(50.3104)
# 	 * Accuracy of candidate # 10  is:  tensor(43.2901)
# 	 * Accuracy of candidate # 11  is:  tensor(47.3942)
# 	 * Accuracy of candidate # 12  is:  tensor(44.1540)
# 	 * Accuracy of candidate # 13  is:  tensor(60.9540)
# 	 * Accuracy of candidate # 14  is:  tensor(41.4446)
# 	 * Accuracy of candidate # 15  is:  tensor(46.4322)
# 	 * Accuracy of candidate # 16  is:  tensor(48.4970)
# 	 * Accuracy of candidate # 17  is:  tensor(52.3567)
# 	 * Accuracy of candidate # 18  is:  tensor(43.4769)
# 	 * Accuracy of candidate # 19  is:  tensor(43.1940)
# 	 * Accuracy of candidate # 20  is:  tensor(47.1973)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 26
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(50.2979)
# 	 * Accuracy of candidate # 2  is:  tensor(40.7031)
# 	 * Accuracy of candidate # 3  is:  tensor(56.1773)
# 	 * Accuracy of candidate # 4  is:  tensor(46.2838)
# 	 * Accuracy of candidate # 5  is:  tensor(41.7277)
# 	 * Accuracy of candidate # 6  is:  tensor(49.2126)
# 	 * Accuracy of candidate # 7  is:  tensor(50.4097)
# 	 * Accuracy of candidate # 8  is:  tensor(42.8674)
# 	 * Accuracy of candidate # 9  is:  tensor(44.6272)
# 	 * Accuracy of candidate # 10  is:  tensor(45.5458)
# 	 * Accuracy of candidate # 11  is:  tensor(53.1858)
# 	 * Accuracy of candidate # 12  is:  tensor(54.8860)
# 	 * Accuracy of candidate # 13  is:  tensor(43.5897)
# 	 * Accuracy of candidate # 14  is:  tensor(49.0620)
# 	 * Accuracy of candidate # 15  is:  tensor(55.1850)
# 	 * Accuracy of candidate # 16  is:  tensor(50.0279)
# 	 * Accuracy of candidate # 17  is:  tensor(50.0477)
# 	 * Accuracy of candidate # 18  is:  tensor(47.6152)
# 	 * Accuracy of candidate # 19  is:  tensor(47.8883)
# 	 * Accuracy of candidate # 20  is:  tensor(48.6946)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 27
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(61.2647)
# 	 * Accuracy of candidate # 2  is:  tensor(46.8683)
# 	 * Accuracy of candidate # 3  is:  tensor(45.3805)
# 	 * Accuracy of candidate # 4  is:  tensor(45.1516)
# 	 * Accuracy of candidate # 5  is:  tensor(52.1899)
# 	 * Accuracy of candidate # 6  is:  tensor(47.0517)
# 	 * Accuracy of candidate # 7  is:  tensor(45.5439)
# 	 * Accuracy of candidate # 8  is:  tensor(45.9990)
# 	 * Accuracy of candidate # 9  is:  tensor(50.5680)
# 	 * Accuracy of candidate # 10  is:  tensor(43.6828)
# 	 * Accuracy of candidate # 11  is:  tensor(43.9939)
# 	 * Accuracy of candidate # 12  is:  tensor(40.9468)
# 	 * Accuracy of candidate # 13  is:  tensor(58.1050)
# 	 * Accuracy of candidate # 14  is:  tensor(49.4042)
# 	 * Accuracy of candidate # 15  is:  tensor(47.1812)
# 	 * Accuracy of candidate # 16  is:  tensor(50.0684)
# 	 * Accuracy of candidate # 17  is:  tensor(45.2092)
# 	 * Accuracy of candidate # 18  is:  tensor(41.2020)
# 	 * Accuracy of candidate # 19  is:  tensor(44.8318)
# 	 * Accuracy of candidate # 20  is:  tensor(54.2561)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 28
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(47.9472)
# 	 * Accuracy of candidate # 2  is:  tensor(55.4697)
# 	 * Accuracy of candidate # 3  is:  tensor(46.3664)
# 	 * Accuracy of candidate # 4  is:  tensor(50.1842)
# 	 * Accuracy of candidate # 5  is:  tensor(45.2479)
# 	 * Accuracy of candidate # 6  is:  tensor(43.5844)
# 	 * Accuracy of candidate # 7  is:  tensor(51.9859)
# 	 * Accuracy of candidate # 8  is:  tensor(48.5540)
# 	 * Accuracy of candidate # 9  is:  tensor(48.2959)
# 	 * Accuracy of candidate # 10  is:  tensor(50.9414)
# 	 * Accuracy of candidate # 11  is:  tensor(50.3381)
# 	 * Accuracy of candidate # 12  is:  tensor(42.0542)
# 	 * Accuracy of candidate # 13  is:  tensor(51.6051)
# 	 * Accuracy of candidate # 14  is:  tensor(44.7147)
# 	 * Accuracy of candidate # 15  is:  tensor(60.0313)
# 	 * Accuracy of candidate # 16  is:  tensor(50.2949)
# 	 * Accuracy of candidate # 17  is:  tensor(47.9573)
# 	 * Accuracy of candidate # 18  is:  tensor(43.2885)
# 	 * Accuracy of candidate # 19  is:  tensor(49.1666)
# 	 * Accuracy of candidate # 20  is:  tensor(53.9511)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 29
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(50.0422)
# 	 * Accuracy of candidate # 2  is:  tensor(39.6674)
# 	 * Accuracy of candidate # 3  is:  tensor(44.7838)
# 	 * Accuracy of candidate # 4  is:  tensor(42.9635)
# 	 * Accuracy of candidate # 5  is:  tensor(48.5476)
# 	 * Accuracy of candidate # 6  is:  tensor(41.4733)
# 	 * Accuracy of candidate # 7  is:  tensor(44.8873)
# 	 * Accuracy of candidate # 8  is:  tensor(42.8240)
# 	 * Accuracy of candidate # 9  is:  tensor(51.9758)
# 	 * Accuracy of candidate # 10  is:  tensor(41.5899)
# 	 * Accuracy of candidate # 11  is:  tensor(48.8841)
# 	 * Accuracy of candidate # 12  is:  tensor(50.2653)
# 	 * Accuracy of candidate # 13  is:  tensor(46.5591)
# 	 * Accuracy of candidate # 14  is:  tensor(42.8043)
# 	 * Accuracy of candidate # 15  is:  tensor(52.7408)
# 	 * Accuracy of candidate # 16  is:  tensor(44.0539)
# 	 * Accuracy of candidate # 17  is:  tensor(55.0048)
# 	 * Accuracy of candidate # 18  is:  tensor(51.8210)
# 	 * Accuracy of candidate # 19  is:  tensor(49.5145)
# 	 * Accuracy of candidate # 20  is:  tensor(51.7769)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 30
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(50.6924)
# 	 * Accuracy of candidate # 2  is:  tensor(49.0433)
# 	 * Accuracy of candidate # 3  is:  tensor(46.9343)
# 	 * Accuracy of candidate # 4  is:  tensor(46.1758)
# 	 * Accuracy of candidate # 5  is:  tensor(44.3572)
# 	 * Accuracy of candidate # 6  is:  tensor(51.3875)
# 	 * Accuracy of candidate # 7  is:  tensor(54.4800)
# 	 * Accuracy of candidate # 8  is:  tensor(54.0241)
# 	 * Accuracy of candidate # 9  is:  tensor(49.4390)
# 	 * Accuracy of candidate # 10  is:  tensor(46.6630)
# 	 * Accuracy of candidate # 11  is:  tensor(46.7838)
# 	 * Accuracy of candidate # 12  is:  tensor(51.3154)
# 	 * Accuracy of candidate # 13  is:  tensor(48.4467)
# 	 * Accuracy of candidate # 14  is:  tensor(42.8577)
# 	 * Accuracy of candidate # 15  is:  tensor(51.6940)
# 	 * Accuracy of candidate # 16  is:  tensor(44.9055)
# 	 * Accuracy of candidate # 17  is:  tensor(46.1507)
# 	 * Accuracy of candidate # 18  is:  tensor(47.3426)
# 	 * Accuracy of candidate # 19  is:  tensor(52.5007)
# 	 * Accuracy of candidate # 20  is:  tensor(53.2861)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 31
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(51.7533)
# 	 * Accuracy of candidate # 2  is:  tensor(46.3345)
# 	 * Accuracy of candidate # 3  is:  tensor(44.6324)
# 	 * Accuracy of candidate # 4  is:  tensor(46.1232)
# 	 * Accuracy of candidate # 5  is:  tensor(44.0506)
# 	 * Accuracy of candidate # 6  is:  tensor(43.9055)
# 	 * Accuracy of candidate # 7  is:  tensor(48.9185)
# 	 * Accuracy of candidate # 8  is:  tensor(46.7366)
# 	 * Accuracy of candidate # 9  is:  tensor(55.1035)
# 	 * Accuracy of candidate # 10  is:  tensor(49.7155)
# 	 * Accuracy of candidate # 11  is:  tensor(47.9330)
# 	 * Accuracy of candidate # 12  is:  tensor(46.5243)
# 	 * Accuracy of candidate # 13  is:  tensor(49.9781)
# 	 * Accuracy of candidate # 14  is:  tensor(49.6527)
# 	 * Accuracy of candidate # 15  is:  tensor(46.8408)
# 	 * Accuracy of candidate # 16  is:  tensor(44.2244)
# 	 * Accuracy of candidate # 17  is:  tensor(44.1344)
# 	 * Accuracy of candidate # 18  is:  tensor(53.4371)
# 	 * Accuracy of candidate # 19  is:  tensor(40.0659)
# 	 * Accuracy of candidate # 20  is:  tensor(42.3708)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 32
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(52.0078)
# 	 * Accuracy of candidate # 2  is:  tensor(47.5088)
# 	 * Accuracy of candidate # 3  is:  tensor(47.7943)
# 	 * Accuracy of candidate # 4  is:  tensor(51.9611)
# 	 * Accuracy of candidate # 5  is:  tensor(48.1326)
# 	 * Accuracy of candidate # 6  is:  tensor(46.7491)
# 	 * Accuracy of candidate # 7  is:  tensor(54.4201)
# 	 * Accuracy of candidate # 8  is:  tensor(44.1782)
# 	 * Accuracy of candidate # 9  is:  tensor(47.3872)
# 	 * Accuracy of candidate # 10  is:  tensor(40.4180)
# 	 * Accuracy of candidate # 11  is:  tensor(48.4761)
# 	 * Accuracy of candidate # 12  is:  tensor(47.5495)
# 	 * Accuracy of candidate # 13  is:  tensor(48.7767)
# 	 * Accuracy of candidate # 14  is:  tensor(57.2739)
# 	 * Accuracy of candidate # 15  is:  tensor(45.2469)
# 	 * Accuracy of candidate # 16  is:  tensor(43.8231)
# 	 * Accuracy of candidate # 17  is:  tensor(44.2328)
# 	 * Accuracy of candidate # 18  is:  tensor(48.7261)
# 	 * Accuracy of candidate # 19  is:  tensor(42.2928)
# 	 * Accuracy of candidate # 20  is:  tensor(45.9335)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 33
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(46.8920)
# 	 * Accuracy of candidate # 2  is:  tensor(47.9359)
# 	 * Accuracy of candidate # 3  is:  tensor(46.8234)
# 	 * Accuracy of candidate # 4  is:  tensor(51.1641)
# 	 * Accuracy of candidate # 5  is:  tensor(46.5108)
# 	 * Accuracy of candidate # 6  is:  tensor(47.5204)
# 	 * Accuracy of candidate # 7  is:  tensor(44.8968)
# 	 * Accuracy of candidate # 8  is:  tensor(44.4971)
# 	 * Accuracy of candidate # 9  is:  tensor(51.9899)
# 	 * Accuracy of candidate # 10  is:  tensor(50.4996)
# 	 * Accuracy of candidate # 11  is:  tensor(44.4015)
# 	 * Accuracy of candidate # 12  is:  tensor(44.5054)
# 	 * Accuracy of candidate # 13  is:  tensor(49.1363)
# 	 * Accuracy of candidate # 14  is:  tensor(47.6681)
# 	 * Accuracy of candidate # 15  is:  tensor(42.4650)
# 	 * Accuracy of candidate # 16  is:  tensor(46.6980)
# 	 * Accuracy of candidate # 17  is:  tensor(45.6736)
# 	 * Accuracy of candidate # 18  is:  tensor(62.1423)
# 	 * Accuracy of candidate # 19  is:  tensor(48.8689)
# 	 * Accuracy of candidate # 20  is:  tensor(43.5348)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 34
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(43.5429)
# 	 * Accuracy of candidate # 2  is:  tensor(47.5880)
# 	 * Accuracy of candidate # 3  is:  tensor(51.3373)
# 	 * Accuracy of candidate # 4  is:  tensor(49.0287)
# 	 * Accuracy of candidate # 5  is:  tensor(43.1714)
# 	 * Accuracy of candidate # 6  is:  tensor(48.3696)
# 	 * Accuracy of candidate # 7  is:  tensor(47.0727)
# 	 * Accuracy of candidate # 8  is:  tensor(46.0676)
# 	 * Accuracy of candidate # 9  is:  tensor(54.2673)
# 	 * Accuracy of candidate # 10  is:  tensor(52.3327)
# 	 * Accuracy of candidate # 11  is:  tensor(55.7833)
# 	 * Accuracy of candidate # 12  is:  tensor(51.2747)
# 	 * Accuracy of candidate # 13  is:  tensor(52.5985)
# 	 * Accuracy of candidate # 14  is:  tensor(52.1712)
# 	 * Accuracy of candidate # 15  is:  tensor(49.4539)
# 	 * Accuracy of candidate # 16  is:  tensor(58.8648)
# 	 * Accuracy of candidate # 17  is:  tensor(44.0128)
# 	 * Accuracy of candidate # 18  is:  tensor(47.4003)
# 	 * Accuracy of candidate # 19  is:  tensor(51.5535)
# 	 * Accuracy of candidate # 20  is:  tensor(49.1176)
#
# 	Best Point Performs: 68.3356704711914
# Optimization iteration: 35
# ----- Calculating Next Candidates Point From the Posterior PDF ... [COMPLETED]
# 	 * Accuracy of candidate # 1  is:  tensor(52.4071)
# 	 * Accuracy of candidate # 2  is:  tensor(54.2814)
# 	 * Accuracy of candidate # 3  is:  tensor(48.2898)
# 	 * Accuracy of candidate # 4  is:  tensor(50.9214)
# 	 * Accuracy of candidate # 5  is:  tensor(44.8452)
# 	 * Accuracy of candidate # 6  is:
